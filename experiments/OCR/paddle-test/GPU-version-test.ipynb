# %%
from paddleocr import PaddleOCR

ocr = PaddleOCR(lang="en")
print("Success!")
# Out:
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Using official model (PP-LCNet_x1_0_doc_ori), the model files will be automatically downloaded and saved in /home/sadin/.paddlex/official_models.
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Creating model: ('UVDoc', None)
# Using official model (UVDoc), the model files will be automatically downloaded and saved in /home/sadin/.paddlex/official_models.
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Creating model: ('PP-LCNet_x1_0_textline_ori', None)
# Using official model (PP-LCNet_x1_0_textline_ori), the model files will be automatically downloaded and saved in /home/sadin/.paddlex/official_models.
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# ...

# %%
from paddleocr import PaddleOCR

print("Creating OCR...")
ocr = PaddleOCR(lang="en")
print("OCR created successfully!")
# Out:
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Using official model (PP-LCNet_x1_0_doc_ori), the model files will be automatically downloaded and saved in /home/sadin/.paddlex/official_models.
# Creating OCR...
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Creating model: ('UVDoc', None)
# Using official model (UVDoc), the model files will be automatically downloaded and saved in /home/sadin/.paddlex/official_models.
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Creating model: ('PP-LCNet_x1_0_textline_ori', None)
# Using official model (PP-LCNet_x1_0_textline_ori), the model files will be automatically downloaded and saved in /home/sadin/.paddlex/official_models.
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# ...

# %%
from paddleocr import PaddleOCR

ocr = PaddleOCR(lang="en")
result = ocr.predict("/run/media/sadin/01DB4814D2F13310/OpenLearn/OpenLearn-AI/experiments/OCR/benchmarks/1.png")

print(type(result))
print(type(result[0]))
print(result[0].keys())

for line in result[0]["rec_texts"]:
    print(line)
# Out:
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Using official model (PP-LCNet_x1_0_doc_ori), the model files will be automatically downloaded and saved in /home/sadin/.paddlex/official_models.
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Creating model: ('UVDoc', None)
# Using official model (UVDoc), the model files will be automatically downloaded and saved in /home/sadin/.paddlex/official_models.
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Creating model: ('PP-LCNet_x1_0_textline_ori', None)
# Using official model (PP-LCNet_x1_0_textline_ori), the model files will be automatically downloaded and saved in /home/sadin/.paddlex/official_models.
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# ...

# %%
for line in result[0]["rec_texts"]:
    print(line)
# Out:
# Why
# ANN?
# There is still too much information unknown about how the brain trains itself to process information.
# In human brains:
# typically a neuron collects signals from others via a host of fine structures known as dendrites.
# each neuron transmits out spikes of electrical signals via a long strand called an axon (split into
# thousands of branches).
# a structure termed a synapse, at the end of each branch, is responsible for converting axon activities
# to electrical effects inhibiting or exciting activities in the connected neurons.
# once a neuron receives an exciting input comparatively large to the inhibiting input, the neuron
# transmits a spike of electrical signals to its axon.
# it is commonly known that learning happens by changing the synapse effect such that the effect of
# one neuron on another changes.

# %%
from pprint import pprint

pprint(result[0])
# Out:
# {'doc_preprocessor_res': {'angle': 0,
#                           'input_img': array([[[255, ..., 255],
#         ...,
#         [255, ..., 255]],
#
#        ...,
#
#        [[255, ..., 255],
#         ...,
#         [255, ..., 255]]], shape=(959, 1758, 3), dtype=uint8),
#                           'input_path': None,
#                           'model_settings': {'use_doc_orientation_classify': True,
#                                              'use_doc_unwarping': True},
#                           'output_img': array([[[255, ..., 255],
#         ...,
#         [255, ..., 255]],
#
#        ...,
#
#        [[255, ..., 255],
#         ...,
#         [255, ..., 255]]], shape=(959, 1758, 3), dtype=uint8),
#                           'page_index': None,
#                           'rot_img': array([[[255, ..., 255],
#         ...,
#         [255, ..., 255]],
#
#        ...,
#
#        [[255, ..., 255],
#         ...,
#         [255, ..., 255]]], shape=(959, 1758, 3), dtype=uint8)},
# ...

# %%
from paddleocr import PaddleOCR

ocr = PaddleOCR(lang="ar")
result = ocr.predict("/run/media/sadin/01DB4814D2F13310/OpenLearn/OpenLearn-AI/experiments/OCR/benchmarks/ar.png")

pprint(result[0])
# Out:
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Using official model (PP-LCNet_x1_0_doc_ori), the model files will be automatically downloaded and saved in /home/sadin/.paddlex/official_models.
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Creating model: ('UVDoc', None)
# Using official model (UVDoc), the model files will be automatically downloaded and saved in /home/sadin/.paddlex/official_models.
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Creating model: ('PP-LCNet_x1_0_textline_ori', None)
# Using official model (PP-LCNet_x1_0_textline_ori), the model files will be automatically downloaded and saved in /home/sadin/.paddlex/official_models.
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# ...

# %%
for text in result[0]["rec_texts"]:
    print(text[::-1])
# Out:
# وكالعواصفمن
# فوواععأك
# من
# دوراندون قد حكموافي الماضي نصفوستروسالشّرقي من(رأ
# الغضبحقخليجالشراطينلكنشلطتهم بدأتتتضاء
# قبل قرون عدّة كان ملوك(المرعىيقتطعون من مناطقهم من جه
# الغربوالدورنيُّونيزعجوغهممنالجنوبودفقعهمهارن الأسودورجا
# الحديديُّون عن(التّالوثوأراضيشال(النّهر الأسودكان الملل
# عادية غزو دوري حين كان يافعاء وعبر(البحر الضيّقللانضمام إل

# %%
from bidi.algorithm import get_display
import arabic_reshaper

for text in result[0]["rec_texts"]:
    reshaped = arabic_reshaper.reshape(text)
    display = get_display(reshaped)
    print(display)
# Out:
# ﻮﻛﻼﻋﻭﺎﺼﻔﻤﻧ
# ﻑﻭﻭﺎﻌﻋﺄﻛ
# ﻢﻧ
# ﺩﻭﺭﺎﻧﺩﻮﻧ ﻕﺩ ﺢﻜﻣﻭﺎﻔﻳ ﻼﻣﺎﻀﻳ ﻦﺼﻓﻮﺴﺗﺭﻮﺳﻼﺷﺮﻘﻳ ﻢﻧ)ﺭﺃ
# ﻼﻐﻀﺒﺤﻘﺨﻠﻴﺟﻼﺷﺭﺎﻄﻴﻨﻠﻜﻨﺸﻠﻄﺘﻬﻣ ﺏﺩﺄﺘﺘﺘﺿﺍﺀ
# ﻖﺒﻟ ﻕﺭﻮﻧ ﻉﺩﺓ ﻙﺎﻧ ﻢﻟﻮﻛ)ﻼﻣﺮﻌﯩﻴﻘﺘﻄﻋﻮﻧ ﻢﻧ ﻢﻧﺎﻄﻘﻬﻣ ﻢﻧ ﺞﻫ
# ﻼﻏﺮﺑﻭﻻﺩﻭﺮﻨﻳﻮﻨﻳﺰﻌﺟﻮﻐﻬﻤﻤﻧﻼﺠﻧﻮﺑﻭﺪﻔﻘﻌﻬﻤﻫﺍﺮﻧ ﻻﺄﺳﻭﺩﻭﺮﺟﺍ
# ﻼﺣﺪﻳﺪﻳﻮﻧ ﻊﻧ)ﻼﺗﻻﻮﺛﻭﺃﺭﺎﻀﻴﺷﻻ)ﻼﻨﻫﺭ ﻻﺄﺳﻭﺪﻛﺎﻧ ﻼﻤﻠﻟ
# ﻉﺍﺪﻳﺓ ﻍﺯﻭ ﺩﻭﺮﻳ ﺢﻴﻧ ﻙﺎﻧ ﻱﺎﻔﻋﺍﺀ ﻮﻌﺑﺭ)ﻼﺒﺣﺭ ﻼﻀﻴﻘﻠﻟﺎﻨﻀﻣﺎﻣ ﻹ

# %%
from paddleocr import PaddleOCR

ocr = PaddleOCR(lang="en")
result = ocr.predict("/run/media/sadin/01DB4814D2F13310/OpenLearn/OpenLearn-AI/experiments/OCR/benchmarks/Data+Structre+lect1.pdf")

pprint(result[0])
# Out:
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Using official model (PP-LCNet_x1_0_doc_ori), the model files will be automatically downloaded and saved in /home/sadin/.paddlex/official_models.
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Creating model: ('UVDoc', None)
# Using official model (UVDoc), the model files will be automatically downloaded and saved in /home/sadin/.paddlex/official_models.
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Creating model: ('PP-LCNet_x1_0_textline_ori', None)
# Using official model (PP-LCNet_x1_0_textline_ori), the model files will be automatically downloaded and saved in /home/sadin/.paddlex/official_models.
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# ...

# %%
for text in result[0]["rec_texts"]:
    print(text)
# Out:
# Faculty of
# ArtHiclal inneligunce
#  is i。
# t
# (afrelsheikh Universit:
# K
# afrelsheikh University
# Data Structures
# Dr. Basma M. Hassan
# Faculty of Artificial Intelligence
# Kafrelsheikh University
# 2024/2025
