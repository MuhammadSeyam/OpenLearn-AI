# %%
import pandas as pd

data = [
    {
        "sentence1": "Transformer architectures rely on self-attention mechanisms to capture long-range dependencies within sequential data.",
        "sentence2": "Self-attention enables Transformer models to learn relationships between distant tokens without recurrent computations.",
        "score": 0.96,
    },
    {
        "sentence1": "Gradient checkpointing reduces GPU memory consumption during neural network training by recomputing intermediate activations.",
        "sentence2": "Caching every intermediate activation increases memory usage while decreasing recomputation overhead.",
        "score": 0.31,
    },
    {
        "sentence1": "Approximate nearest neighbor search significantly improves retrieval latency in high-dimensional embedding spaces.",
        "sentence2": "Vector databases commonly employ approximate indexing techniques to accelerate similarity search over embeddings.",
        "score": 0.94,
    },
    {
        "sentence1": "Normalization layers stabilize optimization by reducing internal covariate shift during deep neural network training.",
        "sentence2": "Batch normalization improves convergence by normalizing feature distributions across mini-batches.",
        "score": 0.91,
    },
    {
        "sentence1": "Dynamic programming decomposes optimization problems into overlapping subproblems with optimal substructure.",
        "sentence2": "Greedy algorithms always produce globally optimal solutions regardless of problem structure.",
        "score": 0.18,
    },
    {
        "sentence1": "Distributed consensus algorithms ensure fault-tolerant agreement among replicas despite partial network failures.",
        "sentence2": "Protocols such as Raft and Paxos maintain consistency across replicated distributed systems.",
        "score": 0.95,
    },
    {
        "sentence1": "Contrastive learning encourages semantically similar samples to occupy nearby regions in the embedding space.",
        "sentence2": "Contrastive objectives maximize the distance between positive pairs while minimizing it for unrelated samples.",
        "score": 0.22,
    },
    {
        "sentence1": "Retrieval-Augmented Generation enhances factual accuracy by incorporating external knowledge during inference.",
        "sentence2": "Large language models can retrieve relevant documents before generating grounded responses.",
        "score": 0.93,
    },
    {
        "sentence1": "Compiler optimizations such as loop unrolling aim to reduce execution overhead and improve instruction-level parallelism.",
        "sentence2": "Loop unrolling decreases loop control overhead and may expose additional opportunities for parallel execution.",
        "score": 0.97,
    },
    {
        "sentence1": "Federated learning enables collaborative model training while preserving data locality across participating clients.",
        "sentence2": "Instead of sharing raw datasets, federated learning exchanges model updates between distributed devices.",
        "score": 0.98,
    },
    {
        "sentence1": "A convolutional neural network learns spatial hierarchies by applying shared filters across localized regions of an input image.",
        "sentence2": "CNNs extract increasingly complex visual features through layers of learnable convolutional filters.",
        "score": 0.96,
    },

    {
        "sentence1": "Overfitting occurs when a model memorizes training examples instead of learning patterns that generalize to unseen data.",
        "sentence2": "Underfitting happens when a model is too simple to capture important relationships in the training dataset.",
        "score": 0.36,
    },

    {
        "sentence1": "Regularization techniques constrain model complexity to reduce the risk of overfitting.",
        "sentence2": "Methods such as L1 and L2 penalties discourage excessively complex parameter configurations.",
        "score": 0.92,
    },

    {
        "sentence1": "A binary search tree organizes elements according to an ordering property that enables efficient search operations.",
        "sentence2": "Hash tables provide constant-average-time lookup by mapping keys to positions using a hash function.",
        "score": 0.39,
    },

    {
        "sentence1": "Backpropagation computes gradients of the loss with respect to neural network parameters using the chain rule.",
        "sentence2": "The chain rule allows errors to be propagated backward through successive layers to calculate parameter gradients.",
        "score": 0.98,
    },

    {
        "sentence1": "Dropout randomly disables a subset of neurons during training to prevent excessive dependence on individual features.",
        "sentence2": "Randomly removing activations during training can improve the generalization ability of neural networks.",
        "score": 0.94,
    },

    {
        "sentence1": "A learning rate determines the magnitude of parameter updates performed by an optimization algorithm.",
        "sentence2": "The batch size controls how many training examples contribute to each gradient update.",
        "score": 0.42,
    },

    {
        "sentence1": "Adam combines adaptive learning rates with momentum-based gradient updates to accelerate neural network optimization.",
        "sentence2": "The Adam optimizer maintains moving estimates of gradients and squared gradients for parameter updates.",
        "score": 0.97,
    },

    {
        "sentence1": "A recurrent neural network processes sequential information by maintaining a hidden state that carries information across time steps.",
        "sentence2": "RNNs use recurrent connections to propagate information from previous positions through a sequence.",
        "score": 0.97,
    },

    {
        "sentence1": "Long Short-Term Memory networks address certain limitations of standard recurrent networks by using gated memory cells.",
        "sentence2": "LSTM architectures employ input, forget, and output gates to regulate information stored in their memory states.",
        "score": 0.96,
    },

    {
        "sentence1": "Attention mechanisms assign different importance weights to input elements when constructing an output representation.",
        "sentence2": "Attention allows a model to selectively focus on the most relevant parts of an input sequence.",
        "score": 0.95,
    },

    {
        "sentence1": "Positional encodings provide sequence-order information to Transformer models that process tokens without recurrence.",
        "sentence2": "Transformers require positional representations because self-attention alone does not inherently encode token order.",
        "score": 0.97,
    },

    {
        "sentence1": "Tokenization converts raw text into smaller units that can be mapped to numerical representations for language models.",
        "sentence2": "A tokenizer decomposes textual input into tokens before the sequence is processed by a neural language model.",
        "score": 0.98,
    },

    {
        "sentence1": "Word embeddings represent linguistic units as dense vectors whose geometric relationships can encode semantic information.",
        "sentence2": "Embedding models map words or text fragments into continuous vector spaces where related meanings can be represented closely.",
        "score": 0.93,
    },

    {
        "sentence1": "TF-IDF assigns higher importance to terms that frequently occur in a document but are relatively uncommon across the corpus.",
        "sentence2": "TF-IDF reduces the weight of words that appear across many documents while emphasizing document-specific terms.",
        "score": 0.96,
    },

    {
        "sentence1": "Principal Component Analysis projects high-dimensional observations onto directions that maximize variance.",
        "sentence2": "PCA can reduce dimensionality by transforming correlated features into a smaller set of orthogonal components.",
        "score": 0.91,
    },

    {
        "sentence1": "K-means clustering partitions observations into groups by minimizing the distance between samples and their assigned centroids.",
        "sentence2": "The K-means algorithm iteratively assigns points to nearby cluster centers and updates those centers.",
        "score": 0.98,
    },

    {
        "sentence1": "Hierarchical clustering constructs a nested structure of groups by repeatedly merging or splitting clusters.",
        "sentence2": "Unlike K-means, hierarchical clustering can represent relationships between clusters as a dendrogram.",
        "score": 0.89,
    },

    {
        "sentence1": "Precision measures the proportion of retrieved positive predictions that are actually relevant.",
        "sentence2": "Recall measures the proportion of all relevant instances that were successfully retrieved by the system.",
        "score": 0.47,
    },

    {
        "sentence1": "F1-score combines precision and recall using their harmonic mean.",
        "sentence2": "The F1 metric provides a single score that balances false-positive and false-negative behavior.",
        "score": 0.95,
    },

    {
        "sentence1": "Cross-validation estimates model generalization by repeatedly training and evaluating on different partitions of the dataset.",
        "sentence2": "K-fold validation divides the data into several subsets and rotates the subset used for evaluation.",
        "score": 0.97,
    },

    {
        "sentence1": "Data leakage occurs when information unavailable during real-world prediction is unintentionally incorporated into model training.",
        "sentence2": "Leakage can produce artificially high evaluation results because the model indirectly accesses information from the validation or test data.",
        "score": 0.96,
    },

    {
        "sentence1": "A confusion matrix summarizes classification predictions by counting true positives, true negatives, false positives, and false negatives.",
        "sentence2": "Classification performance can be analyzed by examining how predicted labels correspond to actual class assignments.",
        "score": 0.91,
    },

    {
        "sentence1": "Support Vector Machines construct decision boundaries that maximize the margin between different classes.",
        "sentence2": "An SVM identifies a separating hyperplane that attempts to maximize the distance to the nearest training examples.",
        "score": 0.98,
    },

    {
        "sentence1": "Decision trees recursively partition feature space using conditions selected according to impurity reduction criteria.",
        "sentence2": "Tree-based classifiers split observations into increasingly homogeneous subsets based on feature values.",
        "score": 0.96,
    },

    {
        "sentence1": "Random forests improve robustness by aggregating predictions from multiple decision trees trained on randomized subsets of data and features.",
        "sentence2": "Random forest models combine many independently constructed trees to reduce variance and improve generalization.",
        "score": 0.98,
    },

    {
        "sentence1": "Gradient boosting constructs an ensemble sequentially by fitting new models to errors made by previously trained models.",
        "sentence2": "Boosting algorithms iteratively add weak learners that focus on correcting the mistakes of the current ensemble.",
        "score": 0.97,
    },

    {
        "sentence1": "Principal component analysis is an unsupervised dimensionality reduction method.",
        "sentence2": "Linear regression predicts a continuous target by estimating relationships between dependent and independent variables.",
        "score": 0.14,
    },

    {
        "sentence1": "A convolution operation applies a learnable kernel across an input to detect localized patterns.",
        "sentence2": "Pooling layers reduce spatial dimensions by aggregating information from neighboring activations.",
        "score": 0.58,
    },

    {
        "sentence1": "Batch normalization normalizes intermediate activations using statistics computed from training mini-batches.",
        "sentence2": "Layer normalization normalizes activations across the features of an individual training example.",
        "score": 0.61,
    },

    {
        "sentence1": "Quantization reduces the numerical precision used to represent model parameters and activations.",
        "sentence2": "Model compression can decrease memory requirements and inference costs by representing weights with fewer bits.",
        "score": 0.93,
    },

    {
        "sentence1": "Knowledge distillation trains a smaller student model to reproduce behavior learned by a larger teacher model.",
        "sentence2": "A compact neural network can learn from the predictions or intermediate representations of a more capable pretrained model.",
        "score": 0.96,
    },

    {
        "sentence1": "Fine-tuning adapts a pretrained model to a downstream task by continuing optimization on task-specific data.",
        "sentence2": "Transfer learning commonly initializes a model with previously learned parameters before adapting it to a new dataset.",
        "score": 0.94,
    },

    {
        "sentence1": "Parameter-efficient fine-tuning updates only a small subset of parameters while keeping most pretrained weights fixed.",
        "sentence2": "LoRA reduces the computational cost of adaptation by learning low-rank updates instead of modifying all model parameters.",
        "score": 0.95,
    },

    {
        "sentence1": "Retrieval-Augmented Generation retrieves external information before passing relevant context to a generative language model.",
        "sentence2": "RAG systems combine information retrieval with language generation to produce responses grounded in retrieved documents.",
        "score": 0.99,
    },

    {
        "sentence1": "Dense retrieval represents queries and documents as vectors and compares them using a similarity function.",
        "sentence2": "Semantic search retrieves text based on vector representations rather than relying exclusively on exact keyword matches.",
        "score": 0.94,
    },

    {
        "sentence1": "A reranker evaluates initially retrieved documents using a more computationally expensive relevance model.",
        "sentence2": "Reranking improves search results by reconsidering the ordering of candidates returned by an initial retrieval stage.",
        "score": 0.98,
    },

    {
        "sentence1": "Cosine similarity measures the angular similarity between two vectors regardless of their individual magnitudes.",
        "sentence2": "Two embeddings can have high cosine similarity when they point in nearly the same direction even if their lengths differ.",
        "score": 0.96,
    },

    {
        "sentence1": "Euclidean distance measures the straight-line distance between two points in a vector space.",
        "sentence2": "Cosine similarity compares vector orientation rather than the absolute geometric distance between their endpoints.",
        "score": 0.52,
    },

    {
        "sentence1": "Vector databases are optimized for storing and querying high-dimensional numerical representations.",
        "sentence2": "Traditional relational databases primarily organize structured records using tables, rows, columns, and relational constraints.",
        "score": 0.34,
    },

    {
        "sentence1": "Approximate nearest neighbor algorithms trade a small amount of retrieval accuracy for substantially faster similarity search.",
        "sentence2": "ANN indexing methods accelerate vector search by avoiding exhaustive comparison against every stored embedding.",
        "score": 0.97,
    },

    {
        "sentence1": "The CAP theorem describes a trade-off involving consistency, availability, and partition tolerance in distributed systems.",
        "sentence2": "Distributed databases must consider how network partitions affect consistency and availability guarantees.",
        "score": 0.94,
    },

    {
        "sentence1": "Load balancing distributes incoming requests across multiple servers to prevent individual instances from becoming overloaded.",
        "sentence2": "A load balancer can improve scalability and availability by routing traffic among several backend servers.",
        "score": 0.98,
    },

    {
        "sentence1": "Caching stores frequently accessed data closer to consumers to reduce repeated computation or network access.",
        "sentence2": "A cache can decrease response latency by serving previously retrieved information without contacting the original data source.",
        "score": 0.97,
    },

    {
        "sentence1": "Docker containers isolate applications and their dependencies using operating-system-level virtualization.",
        "sentence2": "Containerization packages software with its required libraries and runtime environment so it can execute consistently across systems.",
        "score": 0.96,
    },

    {
        "sentence1": "Kubernetes automates deployment, scaling, and management of containerized workloads across a cluster.",
        "sentence2": "Container orchestration platforms coordinate the lifecycle and resource allocation of applications running across multiple machines.",
        "score": 0.95,
    },

    {
        "sentence1": "Apache Spark performs distributed data processing by partitioning computations across multiple nodes.",
        "sentence2": "Spark enables large-scale analytics by executing data transformations in parallel across a cluster.",
        "score": 0.97,
    },

    {
        "sentence1": "MapReduce divides large-scale computation into mapping and reducing phases that can execute across distributed workers.",
        "sentence2": "The map phase transforms input records while the reduce phase aggregates intermediate results produced by workers.",
        "score": 0.96,
    },

    {
        "sentence1": "ACID transactions provide guarantees related to atomicity, consistency, isolation, and durability.",
        "sentence2": "Database transaction mechanisms ensure that groups of operations satisfy predefined correctness and persistence guarantees.",
        "score": 0.94,
    },

    {
        "sentence1": "Deadlock occurs when multiple processes wait indefinitely for resources held by one another.",
        "sentence2": "A circular dependency among processes competing for locked resources can prevent all of them from making progress.",
        "score": 0.98,
    },

    {
        "sentence1": "Virtual memory allows processes to use an address space that can exceed the physical memory directly available to the system.",
        "sentence2": "Operating systems use techniques such as paging to map virtual addresses to physical memory locations.",
        "score": 0.95,
    },

    {
        "sentence1": "Public-key cryptography uses separate keys for encryption and decryption, unlike symmetric cryptography.",
        "sentence2": "Asymmetric encryption relies on a mathematically related public key and private key for secure communication.",
        "score": 0.97,
    },

    {
        "sentence1": "Hash functions map arbitrary-length inputs to fixed-size outputs and are commonly used for integrity verification.",
        "sentence2": "Cryptographic hashes produce deterministic fixed-length digests that change significantly when the input is modified.",
        "score": 0.98,
    },
    {
        "sentence1": "Graph neural networks propagate information between connected nodes to learn representations that incorporate graph structure.",
        "sentence2": "GNNs aggregate features from neighboring vertices to construct representations influenced by local graph topology.",
        "score": 0.97,
    },

    {
        "sentence1": "Reinforcement learning optimizes an agent's behavior through interactions with an environment and feedback from rewards.",
        "sentence2": "An RL agent learns a policy by selecting actions and receiving numerical feedback from the environment.",
        "score": 0.98,
    },

    {
        "sentence1": "Q-learning estimates the expected future return of taking an action in a particular state.",
        "sentence2": "Q-learning learns action-value estimates that guide an agent toward decisions with higher long-term rewards.",
        "score": 0.97,
    },

    {
        "sentence1": "Policy gradient methods optimize a parameterized policy directly rather than learning an explicit action-value function.",
        "sentence2": "Actor-based reinforcement learning approaches adjust policy parameters according to gradients of expected cumulative reward.",
        "score": 0.94,
    },

    {
        "sentence1": "Generative adversarial networks consist of a generator and discriminator trained through competing objectives.",
        "sentence2": "GAN training involves a generator producing synthetic samples while a discriminator attempts to distinguish them from real data.",
        "score": 0.99,
    },

    {
        "sentence1": "Variational autoencoders learn probabilistic latent representations by optimizing a reconstruction objective together with a regularization term.",
        "sentence2": "VAEs encode observations into distributions over latent variables and decode samples from those distributions.",
        "score": 0.95,
    },

    {
        "sentence1": "Autoencoders learn compressed representations by reconstructing their input from a lower-dimensional latent representation.",
        "sentence2": "An encoder maps data into a latent space while a decoder attempts to reproduce the original input.",
        "score": 0.98,
    },

    {
        "sentence1": "Mean squared error penalizes the squared difference between predicted and observed continuous values.",
        "sentence2": "MSE computes the average of squared prediction errors across numerical targets.",
        "score": 0.99,
    },

    {
        "sentence1": "Cross-entropy loss measures the discrepancy between predicted probability distributions and target class distributions.",
        "sentence2": "Classification models commonly minimize cross-entropy to assign high probability to the correct class.",
        "score": 0.96,
    },

    {
        "sentence1": "The softmax function converts a vector of logits into a probability distribution whose components sum to one.",
        "sentence2": "Softmax normalizes class scores into probabilities that can be interpreted as relative confidence across categories.",
        "score": 0.97,
    },

    {
        "sentence1": "Sigmoid activation maps scalar inputs into values between zero and one.",
        "sentence2": "The sigmoid function is frequently used to produce probabilities for binary classification tasks.",
        "score": 0.93,
    },

    {
        "sentence1": "ReLU introduces nonlinearity by returning zero for negative inputs while preserving positive values.",
        "sentence2": "Rectified linear units output the input when it is positive and otherwise produce zero.",
        "score": 0.99,
    },

    {
        "sentence1": "Vanishing gradients can prevent early layers of deep networks from receiving sufficiently strong learning signals.",
        "sentence2": "Very small backpropagated derivatives may cause parameters in lower layers to update extremely slowly.",
        "score": 0.97,
    },

    {
        "sentence1": "Exploding gradients occur when derivatives grow excessively during backpropagation through deep or recurrent networks.",
        "sentence2": "Gradient clipping is often used to limit unusually large updates caused by unstable gradient magnitudes.",
        "score": 0.67,
    },

    {
        "sentence1": "Early stopping terminates training when validation performance stops improving for a specified period.",
        "sentence2": "Monitoring validation loss can prevent continued optimization after a model begins to overfit the training data.",
        "score": 0.95,
    },

    {
        "sentence1": "Data augmentation increases training diversity by applying transformations that preserve the underlying class semantics.",
        "sentence2": "Image classification models can generalize better when training examples are randomly cropped, flipped, or otherwise transformed.",
        "score": 0.91,
    },

    {
        "sentence1": "Imbalanced classification datasets contain substantially different numbers of examples across their target classes.",
        "sentence2": "When one class dominates the training data, accuracy may provide a misleading assessment of classifier performance.",
        "score": 0.74,
    },

    {
        "sentence1": "One-hot encoding represents a categorical value using a binary vector with a single active position.",
        "sentence2": "Categorical variables can be transformed into vectors where each category corresponds to a distinct indicator dimension.",
        "score": 0.96,
    },

    {
        "sentence1": "Feature scaling transforms numerical variables so that differences in their original magnitudes have less influence on optimization.",
        "sentence2": "Standardization commonly converts features to approximately zero mean and unit variance.",
        "score": 0.89,
    },

    {
        "sentence1": "Min-max normalization maps numerical features into a predefined interval such as zero to one.",
        "sentence2": "Unlike standardization, min-max scaling uses the observed minimum and maximum values to transform a feature range.",
        "score": 0.82,
    },

    {
        "sentence1": "Linear regression estimates continuous outputs using a weighted combination of input features.",
        "sentence2": "Logistic regression models class probabilities using a linear predictor passed through a nonlinear function.",
        "score": 0.56,
    },

    {
        "sentence1": "Logistic regression is commonly used for binary classification by modeling the probability of a target class.",
        "sentence2": "A logistic model applies the sigmoid function to a linear combination of input variables.",
        "score": 0.96,
    },

    {
        "sentence1": "Naive Bayes classifiers assume conditional independence among features given the target class.",
        "sentence2": "The probabilistic model estimates class likelihoods by combining feature probabilities under an independence assumption.",
        "score": 0.96,
    },

    {
        "sentence1": "Principal component analysis seeks directions that preserve as much variance as possible during dimensionality reduction.",
        "sentence2": "Linear discriminant analysis seeks projections that improve separation between labeled classes.",
        "score": 0.62,
    },

    {
        "sentence1": "Random forests reduce prediction variance by averaging decisions from many decorrelated decision trees.",
        "sentence2": "Bagging ensembles train multiple models on resampled datasets and aggregate their predictions.",
        "score": 0.91,
    },

    {
        "sentence1": "Boosting builds an ensemble incrementally, with later learners focusing on observations that previous learners handled poorly.",
        "sentence2": "Bagging trains base estimators independently and combines them without sequentially correcting previous errors.",
        "score": 0.51,
    },

    {
        "sentence1": "A* search combines the cost accumulated so far with a heuristic estimate of the remaining path cost.",
        "sentence2": "The A-star algorithm prioritizes nodes according to both their known path cost and estimated distance to the goal.",
        "score": 0.99,
    },

    {
        "sentence1": "Breadth-first search explores graph vertices level by level using a queue.",
        "sentence2": "Depth-first search explores as far as possible along a branch before backtracking.",
        "score": 0.49,
    },

    {
        "sentence1": "Dijkstra's algorithm computes shortest paths in graphs with non-negative edge weights.",
        "sentence2": "The algorithm repeatedly selects the currently closest unvisited vertex and relaxes its outgoing edges.",
        "score": 0.97,
    },

    {
        "sentence1": "Topological sorting produces an ordering of vertices in a directed acyclic graph such that every dependency precedes its dependent node.",
        "sentence2": "A DAG can be ordered so that each directed edge points from an earlier vertex to a later vertex.",
        "score": 0.98,
    },

    {
        "sentence1": "A stack follows a last-in-first-out access pattern.",
        "sentence2": "A queue removes elements according to the first-in-first-out principle.",
        "score": 0.21,
    },

    {
        "sentence1": "A heap is a tree-based data structure commonly used to implement priority queues.",
        "sentence2": "Priority queues repeatedly return the element with the highest or lowest priority depending on their ordering rule.",
        "score": 0.89,
    },

    {
        "sentence1": "Hash collisions occur when different keys produce the same hash table index.",
        "sentence2": "Collision resolution strategies such as chaining and open addressing allow multiple keys to share a hash location.",
        "score": 0.97,
    },

    {
        "sentence1": "TCP provides reliable ordered delivery of data between communicating endpoints.",
        "sentence2": "TCP uses acknowledgments, sequence numbers, and retransmissions to provide reliable transport.",
        "score": 0.99,
    },

    {
        "sentence1": "UDP provides a connectionless transport mechanism with lower protocol overhead than TCP.",
        "sentence2": "Unlike TCP, UDP does not inherently guarantee reliable ordered delivery of packets.",
        "score": 0.95,
    },

    {
        "sentence1": "The Domain Name System translates human-readable domain names into network addresses.",
        "sentence2": "DNS allows clients to resolve names such as example.com into corresponding IP addresses.",
        "score": 0.98,
    },

    {
        "sentence1": "HTTP is an application-layer protocol used for exchanging resources between clients and servers.",
        "sentence2": "Web browsers typically communicate with web servers through HTTP or its encrypted variant HTTPS.",
        "score": 0.95,
    },

    {
        "sentence1": "TLS protects network communication by providing encryption, authentication, and integrity guarantees.",
        "sentence2": "HTTPS uses TLS to secure HTTP traffic against interception and unauthorized modification.",
        "score": 0.96,
    },

    {
        "sentence1": "Public-key encryption allows a sender to encrypt information using a recipient's public key.",
        "sentence2": "Only the corresponding private key should be capable of decrypting data encrypted under the recipient's public key.",
        "score": 0.98,
    },

    {
        "sentence1": "A digital signature provides evidence that a message was produced by the holder of a particular private key.",
        "sentence2": "Digital signatures can provide authenticity and integrity by allowing recipients to verify signed data using a public key.",
        "score": 0.97,
    },

    {
        "sentence1": "SQL injection exploits improperly handled user input to manipulate database queries.",
        "sentence2": "Parameterized queries help prevent attackers from altering SQL statements through malicious input.",
        "score": 0.89,
    },

    {
        "sentence1": "Cross-site scripting allows malicious scripts to execute in the context of a victim's browser.",
        "sentence2": "XSS vulnerabilities can occur when untrusted input is inserted into web pages without appropriate output encoding.",
        "score": 0.97,
    },

    {
        "sentence1": "Authentication verifies the identity of a user or system.",
        "sentence2": "Authorization determines which resources or operations an authenticated entity is permitted to access.",
        "score": 0.52,
    },

    {
        "sentence1": "A database index accelerates data retrieval by maintaining an auxiliary structure optimized for searching.",
        "sentence2": "Indexes can improve query performance but introduce additional storage and update overhead.",
        "score": 0.95,
    },

    {
        "sentence1": "Normalization reduces redundant data and organizes relational tables according to dependency constraints.",
        "sentence2": "Database normalization can minimize update anomalies by decomposing poorly structured relations.",
        "score": 0.98,
    },

    {
        "sentence1": "A primary key uniquely identifies each record within a relational database table.",
        "sentence2": "Foreign keys establish relationships between records by referencing a key in another table.",
        "score": 0.57,
    },

    {
        "sentence1": "A database transaction groups multiple operations into a logical unit that should satisfy consistency requirements.",
        "sentence2": "Transactions allow related database modifications to succeed or fail according to defined atomicity guarantees.",
        "score": 0.96,
    },

    {
        "sentence1": "Garbage collection automatically identifies memory that is no longer reachable by a program.",
        "sentence2": "Automatic memory management can reclaim objects that are no longer referenced by active program execution.",
        "score": 0.98,
    },

    {
        "sentence1": "A process is an executing program with its own virtual address space and operating-system-managed resources.",
        "sentence2": "Threads within the same process can share memory while executing independently.",
        "score": 0.67,
    },

    {
        "sentence1": "Multithreading enables a process to execute multiple flows of control concurrently.",
        "sentence2": "Threads can perform different tasks within the same process while sharing its address space.",
        "score": 0.96,
    },

    {
        "sentence1": "A mutex provides mutual exclusion so that only one thread can access a protected critical section at a time.",
        "sentence2": "Locks prevent concurrent threads from modifying shared resources simultaneously when exclusive access is required.",
        "score": 0.97,
    },
    {
        "sentence1": "A compiler translates source code written in a high-level programming language into a lower-level representation that can be executed by a computer.",
        "sentence2": "Compilers transform human-readable programs into machine-oriented code through multiple translation stages.",
        "score": 0.96,
    },
    {
        "sentence1": "An interpreter executes program instructions directly rather than producing a separate native executable beforehand.",
        "sentence2": "Interpreted languages typically evaluate source code or an intermediate representation at runtime.",
        "score": 0.95,
    },
    {
        "sentence1": "Lexical analysis converts a sequence of source characters into tokens that can be processed by later compiler stages.",
        "sentence2": "A lexer identifies constructs such as identifiers, operators, literals, and keywords within source code.",
        "score": 0.97,
    },
    {
        "sentence1": "A parser verifies whether a token sequence conforms to the grammatical rules of a programming language.",
        "sentence2": "Syntax analysis constructs a structural representation of code according to the language grammar.",
        "score": 0.96,
    },
    {
        "sentence1": "An abstract syntax tree represents the hierarchical structure of a program while omitting unnecessary syntactic details.",
        "sentence2": "ASTs capture relationships between programming constructs in a form that compilers can analyze and transform.",
        "score": 0.97,
    },
    {
        "sentence1": "Garbage collection can introduce pauses when the runtime identifies and reclaims unreachable objects.",
        "sentence2": "Automatic memory management may temporarily interrupt application execution while reclaiming unused memory.",
        "score": 0.94,
    },
    {
        "sentence1": "Static typing detects certain type inconsistencies before a program is executed.",
        "sentence2": "A statically typed language performs type checking during compilation or another pre-execution analysis stage.",
        "score": 0.97,
    },
    {
        "sentence1": "Polymorphism allows different object types to respond to the same interface or operation according to their own implementations.",
        "sentence2": "Object-oriented polymorphism enables a common interface to represent multiple concrete behaviors.",
        "score": 0.98,
    },
    {
        "sentence1": "Encapsulation restricts direct access to internal object state and exposes controlled interfaces for interacting with it.",
        "sentence2": "Encapsulation hides implementation details behind public methods or interfaces.",
        "score": 0.97,
    },
    {
        "sentence1": "Inheritance allows a class to derive attributes and behaviors from another class.",
        "sentence2": "Subclassing enables specialized objects to reuse or extend functionality defined by a parent class.",
        "score": 0.98,
    },

    {
        "sentence1": "The time complexity of binary search is logarithmic because the search interval is approximately halved after each comparison.",
        "sentence2": "Binary search reduces the remaining search space exponentially with every iteration.",
        "score": 0.98,
    },
    {
        "sentence1": "Merge sort recursively divides an array and then combines sorted subarrays.",
        "sentence2": "The merge-sort algorithm follows a divide-and-conquer strategy and achieves O(n log n) time complexity.",
        "score": 0.96,
    },
    {
        "sentence1": "Quick sort partitions an array around a selected pivot before recursively sorting the resulting partitions.",
        "sentence2": "The pivot-based partitioning process is the central operation used by quicksort.",
        "score": 0.97,
    },
    {
        "sentence1": "A minimum spanning tree connects all vertices of a weighted graph while minimizing the total edge weight.",
        "sentence2": "MST algorithms construct a connected acyclic subgraph with the smallest possible aggregate edge cost.",
        "score": 0.98,
    },
    {
        "sentence1": "Kruskal's algorithm builds a minimum spanning tree by repeatedly selecting the cheapest edge that does not create a cycle.",
        "sentence2": "Kruskal's method typically processes edges in ascending order and uses a disjoint-set structure to detect cycles.",
        "score": 0.97,
    },
    {
        "sentence1": "Dynamic programming often stores solutions to previously solved subproblems to avoid redundant computation.",
        "sentence2": "Memoization improves recursive algorithms by caching results that would otherwise be recalculated.",
        "score": 0.91,
    },
    {
        "sentence1": "Greedy algorithms make locally optimal choices with the expectation that these choices lead to a globally optimal solution.",
        "sentence2": "A greedy strategy commits to the best-looking decision at each step without generally reconsidering previous choices.",
        "score": 0.96,
    },
    {
        "sentence1": "Backtracking explores candidate solutions incrementally and abandons partial solutions that cannot lead to valid results.",
        "sentence2": "Constraint satisfaction problems can be solved by recursively constructing assignments and reversing decisions that violate constraints.",
        "score": 0.93,
    },
    {
        "sentence1": "Amortized analysis evaluates the average cost of operations over a sequence rather than considering each operation independently.",
        "sentence2": "An operation with occasional expensive executions can still have a low amortized complexity when averaged across many operations.",
        "score": 0.96,
    },
    {
        "sentence1": "An adjacency matrix represents graph connectivity using a two-dimensional structure indexed by pairs of vertices.",
        "sentence2": "For a graph with n vertices, an adjacency matrix requires O(n²) storage.",
        "score": 0.92,
    },

    {
        "sentence1": "CPU caches reduce memory access latency by storing recently or frequently accessed data close to the processor.",
        "sentence2": "Cache hierarchies exploit temporal and spatial locality to improve processor performance.",
        "score": 0.97,
    },
    {
        "sentence1": "Pipelining increases processor throughput by allowing different instruction stages to operate concurrently.",
        "sentence2": "Instruction pipelines overlap the execution of multiple instructions across stages such as fetch, decode, and execution.",
        "score": 0.98,
    },
    {
        "sentence1": "Branch prediction attempts to determine the likely outcome of a conditional instruction before the actual result is known.",
        "sentence2": "Modern processors speculate on control-flow decisions to reduce stalls caused by conditional branches.",
        "score": 0.96,
    },
    {
        "sentence1": "A context switch occurs when the operating system saves the execution state of one task and restores another.",
        "sentence2": "Switching between processes or threads requires the scheduler to preserve and reload execution contexts.",
        "score": 0.97,
    },
    {
        "sentence1": "A semaphore coordinates concurrent execution by maintaining a counter that controls access to shared resources.",
        "sentence2": "Semaphores can be used to synchronize threads or limit the number of tasks accessing a resource simultaneously.",
        "score": 0.96,
    },
    {
        "sentence1": "Race conditions arise when program behavior depends on the timing of concurrent operations accessing shared state.",
        "sentence2": "Unsynchronized threads may produce inconsistent results when they modify common data concurrently.",
        "score": 0.97,
    },
    {
        "sentence1": "A scheduler determines which runnable process or thread should receive processor time.",
        "sentence2": "Operating-system scheduling policies control how CPU resources are allocated among competing tasks.",
        "score": 0.98,
    },
    {
        "sentence1": "Paging divides virtual memory into fixed-size pages that can be mapped to physical memory frames.",
        "sentence2": "Virtual memory systems commonly use page tables to translate virtual addresses into physical addresses.",
        "score": 0.96,
    },
    {
        "sentence1": "A system call provides a controlled interface through which user programs request services from the operating system.",
        "sentence2": "Applications invoke operating-system functionality through mechanisms such as file, process, and memory system calls.",
        "score": 0.97,
    },
    {
        "sentence1": "The kernel is the privileged core of an operating system responsible for managing hardware and fundamental system resources.",
        "sentence2": "Operating-system kernels coordinate resources such as CPU scheduling, memory management, and device access.",
        "score": 0.98,
    },

    {
        "sentence1": "IPv4 addresses consist of 32 bits and are commonly represented using four decimal octets.",
        "sentence2": "An IPv4 address can be written in dotted-decimal notation such as 192.168.1.10.",
        "score": 0.98,
    },
    {
        "sentence1": "IPv6 expands the address space to 128 bits to accommodate the growing number of networked devices.",
        "sentence2": "The IPv6 protocol provides a dramatically larger address space than IPv4.",
        "score": 0.98,
    },
    {
        "sentence1": "NAT allows multiple private hosts to communicate with external networks through a shared public address.",
        "sentence2": "Network address translation modifies address information as packets cross between private and public networks.",
        "score": 0.96,
    },
    {
        "sentence1": "A router forwards packets between different networks based on destination addressing information.",
        "sentence2": "Routers determine suitable next hops for IP packets using routing tables.",
        "score": 0.98,
    },
    {
        "sentence1": "A switch forwards Ethernet frames within a local network based on hardware addresses.",
        "sentence2": "Layer-two switches use MAC address information to direct frames toward appropriate ports.",
        "score": 0.98,
    },
    {
        "sentence1": "Latency represents the time required for data to travel between two points or for an operation to complete.",
        "sentence2": "Network latency is commonly measured as the delay between sending information and receiving the corresponding response.",
        "score": 0.95,
    },
    {
        "sentence1": "Bandwidth describes the maximum rate at which data can theoretically be transmitted over a communication channel.",
        "sentence2": "A network link with higher bandwidth can carry more bits per second under suitable conditions.",
        "score": 0.97,
    },
    {
        "sentence1": "Packet loss occurs when transmitted network packets fail to reach their intended destination.",
        "sentence2": "Congestion, hardware problems, and unreliable communication links can cause packets to be dropped.",
        "score": 0.95,
    },
    {
        "sentence1": "A firewall filters network traffic according to predefined security rules.",
        "sentence2": "Firewalls can block unauthorized connections based on properties such as addresses, ports, and protocols.",
        "score": 0.97,
    },
    {
        "sentence1": "A VPN creates an encrypted communication tunnel between endpoints across an untrusted network.",
        "sentence2": "Virtual private networks can protect traffic from local network observers by encrypting transmitted data.",
        "score": 0.96,
    },

    {
        "sentence1": "A relational database organizes information into tables connected through defined relationships.",
        "sentence2": "Relational data models represent entities and associations using structured relations.",
        "score": 0.97,
    },
    {
        "sentence1": "NoSQL databases are designed to support data models that do not necessarily follow the traditional relational table structure.",
        "sentence2": "Document, key-value, graph, and wide-column databases are common categories of NoSQL systems.",
        "score": 0.91,
    },
    {
        "sentence1": "Database sharding distributes portions of a dataset across multiple servers.",
        "sentence2": "Horizontal partitioning can improve database scalability by spreading records among independent nodes.",
        "score": 0.95,
    },
    {
        "sentence1": "Replication maintains multiple copies of data across different storage nodes.",
        "sentence2": "Database replicas can improve availability and provide additional capacity for read operations.",
        "score": 0.95,
    },
    {
        "sentence1": "A materialized view stores the result of a query physically instead of recomputing it for every request.",
        "sentence2": "Materialized views can accelerate expensive analytical queries at the cost of additional storage and refresh operations.",
        "score": 0.94,
    },
    {
        "sentence1": "An OLTP system is optimized for frequent transactional operations involving relatively small amounts of data.",
        "sentence2": "Online transaction processing systems prioritize fast inserts, updates, deletes, and point queries.",
        "score": 0.97,
    },
    {
        "sentence1": "OLAP systems are designed to support analytical queries over large datasets.",
        "sentence2": "Data warehouses commonly use OLAP workloads to analyze historical information and identify business trends.",
        "score": 0.96,
    },
    {
        "sentence1": "A data warehouse integrates information from multiple sources for analytical reporting and decision support.",
        "sentence2": "Enterprise warehouses centralize historical data so organizations can perform large-scale analytical queries.",
        "score": 0.97,
    },
    {
        "sentence1": "ETL pipelines extract data from source systems, transform it into a suitable representation, and load it into a target system.",
        "sentence2": "Traditional data integration workflows often clean and restructure source records before storing them in analytical platforms.",
        "score": 0.96,
    },
    {
        "sentence1": "ELT loads raw data into a target platform before applying transformations within that platform.",
        "sentence2": "Modern cloud warehouses often perform transformations after ingestion because they provide scalable compute resources.",
        "score": 0.96,
    },

    {
        "sentence1": "A data lake stores large volumes of raw or semi-structured information in its original or near-original form.",
        "sentence2": "Unlike highly curated warehouses, data lakes can retain diverse datasets before their analytical structure is fully defined.",
        "score": 0.96,
    },
    {
        "sentence1": "Apache Kafka is a distributed event-streaming platform designed for high-throughput data ingestion and processing.",
        "sentence2": "Kafka organizes messages into topics and allows producers and consumers to exchange streams of records.",
        "score": 0.98,
    },
    {
        "sentence1": "Airflow represents data workflows as directed acyclic graphs of scheduled tasks.",
        "sentence2": "Apache Airflow is commonly used to orchestrate and monitor dependencies between data pipeline operations.",
        "score": 0.98,
    },
    {
        "sentence1": "A data pipeline can fail because upstream data changes violate assumptions made by downstream transformations.",
        "sentence2": "Schema evolution can break dependent processing jobs when the structure of incoming records changes unexpectedly.",
        "score": 0.91,
    },
    {
        "sentence1": "Stream processing analyzes records continuously as they arrive rather than waiting for a complete batch.",
        "sentence2": "Real-time analytics systems process events incrementally to reduce the delay between data generation and insight.",
        "score": 0.97,
    },

    {
        "sentence1": "Cloud computing provides on-demand access to configurable computing resources over a network.",
        "sentence2": "Cloud platforms allow organizations to provision infrastructure and services without directly owning all underlying hardware.",
        "score": 0.96,
    },
    {
        "sentence1": "Infrastructure as Code defines infrastructure configuration using machine-readable files.",
        "sentence2": "IaC allows servers, networks, and cloud resources to be provisioned reproducibly through declarative or programmatic definitions.",
        "score": 0.98,
    },
    {
        "sentence1": "Continuous integration automatically builds and tests software changes as developers integrate code into a shared repository.",
        "sentence2": "CI pipelines help detect integration problems early by validating changes before they reach later deployment stages.",
        "score": 0.96,
    },
    {
        "sentence1": "Continuous deployment automatically releases validated software changes to production.",
        "sentence2": "A deployment pipeline can publish new application versions without requiring a manual production release step.",
        "score": 0.95,
    },
    {
        "sentence1": "Blue-green deployment maintains two production environments and switches traffic between them during releases.",
        "sentence2": "Blue-green strategies can reduce deployment downtime by preparing a new environment before directing users to it.",
        "score": 0.97,
    },

    {
        "sentence1": "Unit tests verify the behavior of small isolated components of a software system.",
        "sentence2": "A unit test typically checks an individual function, method, or module independently from external dependencies.",
        "score": 0.98,
    },
    {
        "sentence1": "Integration testing evaluates whether multiple software components interact correctly.",
        "sentence2": "Integration tests can reveal failures that are not visible when each component is tested in isolation.",
        "score": 0.96,
    },
    {
        "sentence1": "Regression testing ensures that previously working functionality remains correct after software changes.",
        "sentence2": "Automated regression suites help detect unintended side effects introduced by new implementations.",
        "score": 0.97,
    },
    {
        "sentence1": "An API defines rules through which software components communicate and exchange data.",
        "sentence2": "Application programming interfaces expose operations or resources that can be consumed by other programs.",
        "score": 0.98,
    },
    {
        "sentence1": "RESTful APIs commonly represent resources using HTTP methods such as GET, POST, PUT, and DELETE.",
        "sentence2": "REST architectures use standard web mechanisms to manipulate and retrieve representations of resources.",
        "score": 0.96,
    },

    {
        "sentence1": "A convolutional neural network can preserve local spatial relationships through its receptive fields.",
        "sentence2": "Convolutional layers connect each neuron to a restricted region of the preceding feature map.",
        "score": 0.97,
    },
    {
        "sentence1": "Object detection identifies both the categories and locations of objects within an image.",
        "sentence2": "Detection models typically predict bounding boxes along with class probabilities.",
        "score": 0.98,
    },
    {
        "sentence1": "Semantic segmentation assigns a class label to each pixel of an image.",
        "sentence2": "Image segmentation produces dense spatial predictions that identify the category associated with individual pixels.",
        "score": 0.98,
    },
    {
        "sentence1": "Optical character recognition converts visual representations of text into machine-readable characters.",
        "sentence2": "OCR systems detect and recognize printed or handwritten text from images or scanned documents.",
        "score": 0.98,
    },
    {
        "sentence1": "Image augmentation can improve computer vision models by exposing them to varied transformations of training examples.",
        "sentence2": "Techniques such as rotation, cropping, and color perturbation can increase the diversity of visual training data.",
        "score": 0.97,
    },

    {
        "sentence1": "Named entity recognition identifies spans of text corresponding to categories such as people, organizations, and locations.",
        "sentence2": "NER models assign semantic entity types to relevant phrases within natural language input.",
        "score": 0.98,
    },
    {
        "sentence1": "Sentiment analysis determines the emotional or evaluative polarity expressed in a piece of text.",
        "sentence2": "A sentiment classifier may label a review as positive, negative, or neutral.",
        "score": 0.96,
    },
    {
        "sentence1": "Machine translation automatically converts text from one natural language into another.",
        "sentence2": "Neural translation systems learn mappings between source-language sequences and target-language sequences.",
        "score": 0.96,
    },
    {
        "sentence1": "Text summarization produces a shorter representation that preserves important information from a longer document.",
        "sentence2": "Summarization systems identify or generate concise text capturing the main ideas of the source.",
        "score": 0.98,
    },
    {
        "sentence1": "Question answering systems retrieve or generate responses to questions expressed in natural language.",
        "sentence2": "QA models can identify relevant passages or generate answers based on contextual information.",
        "score": 0.95,
    },

    {
        "sentence1": "Self-supervised learning creates training signals from the structure or content of unlabeled data.",
        "sentence2": "Pretraining objectives can generate pseudo-labels automatically without requiring manual annotation for every example.",
        "score": 0.95,
    },
    {
        "sentence1": "Unsupervised learning discovers patterns in data without using explicit target labels during training.",
        "sentence2": "Clustering and dimensionality reduction are common examples of methods that can operate without labeled outcomes.",
        "score": 0.96,
    },
    {
        "sentence1": "Semi-supervised learning combines a relatively small labeled dataset with a larger collection of unlabeled examples.",
        "sentence2": "Semi-supervised methods attempt to exploit unlabeled data to improve learning when manual annotations are limited.",
        "score": 0.98,
    },
    {
        "sentence1": "Active learning selects the most informative examples for human annotation instead of labeling the entire dataset.",
        "sentence2": "An active learning system can reduce annotation costs by asking an oracle to label strategically chosen samples.",
        "score": 0.98,
    },
    {
        "sentence1": "Transfer learning allows knowledge learned from one task or dataset to improve performance on another related task.",
        "sentence2": "A pretrained representation can serve as the starting point for solving a downstream problem with limited data.",
        "score": 0.97,
    },

    {
        "sentence1": "Model calibration measures whether predicted probabilities correspond to actual event frequencies.",
        "sentence2": "A well-calibrated classifier should produce predictions whose confidence levels reflect empirical correctness rates.",
        "score": 0.98,
    },
    {
        "sentence1": "ROC curves illustrate the trade-off between true-positive and false-positive rates across classification thresholds.",
        "sentence2": "Changing the decision threshold produces different sensitivity and false-alarm rates that can be visualized with an ROC curve.",
        "score": 0.98,
    },
    {
        "sentence1": "A precision-recall curve is particularly informative when positive examples are rare.",
        "sentence2": "PR curves show how precision changes as recall varies across different classification thresholds.",
        "score": 0.97,
    },
    {
        "sentence1": "Model drift occurs when the statistical properties of incoming data change after deployment.",
        "sentence2": "A production model may become less accurate when real-world data distributions differ substantially from those observed during training.",
        "score": 0.96,
    },
    {
        "sentence1": "Concept drift occurs when the relationship between input features and the target variable changes over time.",
        "sentence2": "A predictive model can degrade when the underlying rule connecting observations to outcomes evolves after deployment.",
        "score": 0.98,
    },

    {
        "sentence1": "Explainable AI methods attempt to make model predictions more understandable to humans.",
        "sentence2": "Interpretability techniques can reveal which input features contributed to a machine learning prediction.",
        "score": 0.96,
    },
    {
        "sentence1": "Feature importance estimates quantify how strongly individual input variables influence a model's predictions.",
        "sentence2": "Tree-based models can rank features according to their contribution to reducing impurity during splitting.",
        "score": 0.90,
    },
    {
        "sentence1": "Adversarial examples are inputs intentionally modified to cause machine learning models to make incorrect predictions.",
        "sentence2": "Small perturbations that are often difficult for humans to notice can cause neural classifiers to produce wrong outputs.",
        "score": 0.98,
    },
    {
        "sentence1": "Differential privacy limits the influence of individual records on released statistical or machine learning results.",
        "sentence2": "Privacy-preserving algorithms can add carefully controlled noise so that information about any single participant is harder to infer.",
        "score": 0.94,
    },
    {
        "sentence1": "Federated learning keeps training data on participating devices while coordinating model updates across clients.",
        "sentence2": "Distributed clients can collaboratively optimize a shared model without directly sending their raw datasets to a central server.",
        "score": 0.98,
    },

    {
        "sentence1": "A microservices architecture decomposes an application into independently deployable services organized around specific capabilities.",
        "sentence2": "Instead of one large application, microservices separate functionality into smaller services that communicate through defined interfaces.",
        "score": 0.98,
    },
    {
        "sentence1": "A monolithic application packages most of its functionality into a single deployable unit.",
        "sentence2": "In a monolith, components are typically released together rather than being independently deployed services.",
        "score": 0.96,
    },
    {
        "sentence1": "Message queues decouple producers from consumers by allowing messages to be stored until they can be processed.",
        "sentence2": "Asynchronous messaging can prevent a producer from blocking while a downstream service handles previously submitted work.",
        "score": 0.97,
    },
    {
        "sentence1": "Idempotent operations can be executed multiple times without changing the final result beyond the first successful execution.",
        "sentence2": "Idempotency is useful in distributed systems because retrying the same request does not necessarily create additional side effects.",
        "score": 0.97,
    },
    {
        "sentence1": "Horizontal scaling increases capacity by adding more instances of a service.",
        "sentence2": "Vertical scaling increases the resources assigned to an existing machine or instance.",
        "score": 0.35,
    },

    {
        "sentence1": "A compiler converts source code into a representation that can be executed by a target machine.",
        "sentence2": "A database index accelerates searches by maintaining an auxiliary data structure.",
        "score": 0.05,
    },
    {
        "sentence1": "Gradient descent updates model parameters according to the direction of the loss gradient.",
        "sentence2": "DNS resolves domain names into network addresses.",
        "score": 0.04,
    },
    {
        "sentence1": "Convolutional layers detect local spatial patterns in images.",
        "sentence2": "A relational database organizes records into tables.",
        "score": 0.06,
    },
    {
        "sentence1": "TCP provides reliable ordered delivery between network endpoints.",
        "sentence2": "K-means assigns observations to clusters based on distances to centroids.",
        "score": 0.03,
    },
    {
        "sentence1": "Transformers use attention mechanisms to model relationships between tokens.",
        "sentence2": "A CPU cache stores frequently accessed data near the processor.",
        "score": 0.09,
    },
    {
        "sentence1": "Operating systems manage processes, memory, and hardware resources.",
        "sentence2": "Softmax converts logits into normalized class probabilities.",
        "score": 0.05,
    },
    {
        "sentence1": "SQL joins combine records from multiple relational tables.",
        "sentence2": "Backpropagation computes derivatives for neural network parameters.",
        "score": 0.04,
    },
    {
        "sentence1": "A hash table provides efficient average-case lookup using a hash function.",
        "sentence2": "A convolutional neural network learns hierarchical visual representations.",
        "score": 0.06,
    },
    {
        "sentence1": "Kubernetes orchestrates containerized workloads across computing clusters.",
        "sentence2": "TF-IDF assigns weights to terms according to their distribution across documents.",
        "score": 0.05,
    },
    {
        "sentence1": "PCA reduces dimensionality by projecting data onto principal directions.",
        "sentence2": "A firewall filters network traffic according to security policies.",
        "score": 0.04,
    },

    {
        "sentence1": "A* search uses heuristic estimates to prioritize nodes during path finding.",
        "sentence2": "Batch normalization standardizes intermediate neural network activations.",
        "score": 0.07,
    },
    {
        "sentence1": "Docker packages applications and dependencies into portable containers.",
        "sentence2": "Dijkstra's algorithm computes shortest paths using non-negative edge weights.",
        "score": 0.08,
    },
    {
        "sentence1": "A mutex prevents multiple threads from simultaneously entering a protected critical section.",
        "sentence2": "An embedding model maps text into a continuous vector space.",
        "score": 0.06,
    },
    {
        "sentence1": "OLAP systems are designed for analytical queries over large datasets.",
        "sentence2": "ReLU outputs zero for negative inputs and preserves positive values.",
        "score": 0.05,
    },
    {
        "sentence1": "A neural language model predicts or generates sequences of tokens.",
        "sentence2": "A router forwards packets between different computer networks.",
        "score": 0.07,
    },
    {
        "sentence1": "Object detection predicts object categories and bounding boxes in images.",
        "sentence2": "A transaction groups database operations into a logical unit.",
        "score": 0.05,
    },
    {
        "sentence1": "Apache Kafka enables distributed event streaming between producers and consumers.",
        "sentence2": "Random forests aggregate predictions from multiple decision trees.",
        "score": 0.08,
    },
    {
        "sentence1": "A virtual machine emulates or abstracts computer hardware for an operating system.",
        "sentence2": "Named entity recognition identifies people, locations, and organizations in text.",
        "score": 0.04,
    },
    {
        "sentence1": "Regularization reduces model complexity to improve generalization.",
        "sentence2": "IPv6 uses 128-bit addresses to provide a larger address space.",
        "score": 0.06,
    },
    {
        "sentence1": "A queue follows a first-in-first-out access pattern.",
        "sentence2": "A cryptographic hash produces a fixed-length digest from arbitrary input data.",
        "score": 0.05,
    },

    {
        "sentence1": "Semantic segmentation assigns a category to individual image pixels.",
        "sentence2": "Gradient boosting builds an ensemble by adding learners sequentially.",
        "score": 0.09,
    },
    {
        "sentence1": "A primary key uniquely identifies records in a relational table.",
        "sentence2": "The sigmoid function maps values into the interval between zero and one.",
        "score": 0.06,
    },
    {
        "sentence1": "Federated learning trains a shared model across decentralized clients.",
        "sentence2": "Merge sort recursively divides and combines arrays.",
        "score": 0.05,
    },
    {
        "sentence1": "A VPN encrypts traffic transmitted across an untrusted network.",
        "sentence2": "An autoencoder learns to reconstruct its input from a latent representation.",
        "score": 0.07,
    },
    {
        "sentence1": "Unit tests verify individual software components in isolation.",
        "sentence2": "The CAP theorem describes trade-offs in distributed systems.",
        "score": 0.08,
    },
    {
        "sentence1": "An adjacency matrix represents graph connectivity using a two-dimensional array.",
        "sentence2": "Cross-entropy measures the discrepancy between predicted and target distributions.",
        "score": 0.05,
    },
    {
        "sentence1": "Data augmentation increases training diversity through transformations of existing examples.",
        "sentence2": "A load balancer distributes requests among multiple servers.",
        "score": 0.08,
    },
    {
        "sentence1": "A garbage collector reclaims memory occupied by unreachable objects.",
        "sentence2": "A convolutional filter detects local patterns within an image.",
        "score": 0.07,
    },
    {
        "sentence1": "An API defines how software components communicate with one another.",
        "sentence2": "A decision tree recursively partitions data using feature-based conditions.",
        "score": 0.06,
    },
    {
        "sentence1": "A data warehouse stores integrated historical data for analytical workloads.",
        "sentence2": "An LSTM uses gated memory cells to process sequential information.",
        "score": 0.05,
    },

    {
        "sentence1": "The operating system scheduler allocates CPU time among runnable tasks.",
        "sentence2": "The softmax function produces a probability distribution from model logits.",
        "score": 0.04,
    },
    {
        "sentence1": "A database replica maintains another copy of stored information.",
        "sentence2": "A tokenizer splits text into units that can be processed by a language model.",
        "score": 0.05,
    },
    {
        "sentence1": "Cross-validation evaluates a model using multiple train-validation partitions.",
        "sentence2": "A router determines where network packets should be forwarded.",
        "score": 0.08,
    },
    {
        "sentence1": "A semaphore can regulate access to a limited shared resource.",
        "sentence2": "An image classifier predicts the category associated with an input image.",
        "score": 0.06,
    },
    {
        "sentence1": "A foreign key establishes a relationship between records in different database tables.",
        "sentence2": "A Transformer uses self-attention to process sequences.",
        "score": 0.05,
    },
    {
        "sentence1": "MapReduce divides distributed computation into mapping and reducing stages.",
        "sentence2": "An SVM searches for a decision boundary with a large classification margin.",
        "score": 0.07,
    },
    {
        "sentence1": "An operating system uses paging to map virtual addresses to physical memory.",
        "sentence2": "Precision measures the fraction of predicted positives that are relevant.",
        "score": 0.06,
    },
    {
        "sentence1": "A digital signature provides evidence of message authenticity and integrity.",
        "sentence2": "A heap is commonly used to implement priority queues.",
        "score": 0.05,
    },
    {
        "sentence1": "Continuous integration automatically builds and tests software changes.",
        "sentence2": "PCA identifies directions of maximum variance in numerical data.",
        "score": 0.06,
    },
    {
        "sentence1": "A message queue allows producers and consumers to operate asynchronously.",
        "sentence2": "A convolutional network extracts visual features through learned filters.",
        "score": 0.09,
    },

    {
        "sentence1": "The vanishing gradient problem can make optimization difficult in deep networks.",
        "sentence2": "A DNS server resolves hostnames into corresponding IP addresses.",
        "score": 0.04,
    },
    {
        "sentence1": "Attention mechanisms allow models to assign different importance to input elements.",
        "sentence2": "A binary tree stores elements according to hierarchical relationships.",
        "score": 0.06,
    },
    {
        "sentence1": "A NoSQL database may use documents instead of normalized relational tables.",
        "sentence2": "Gradient clipping limits unusually large parameter updates.",
        "score": 0.05,
    },
    {
        "sentence1": "Load balancing distributes incoming traffic across multiple service instances.",
        "sentence2": "Named entity recognition assigns semantic categories to text spans.",
        "score": 0.04,
    },
    {
        "sentence1": "A compiler performs syntax analysis before generating lower-level code.",
        "sentence2": "An embedding represents semantic information using a dense numerical vector.",
        "score": 0.08,
    },
    {
        "sentence1": "The precision metric focuses on the correctness of retrieved positive predictions.",
        "sentence2": "A process is an executing instance of a computer program.",
        "score": 0.07,
    },
    {
        "sentence1": "A microservices architecture divides an application into independently deployable services.",
        "sentence2": "A random forest combines predictions from multiple decision trees.",
        "score": 0.10,
    },
    {
        "sentence1": "TLS provides encryption and integrity for network communication.",
        "sentence2": "A neural network optimizer adjusts parameters using gradients.",
        "score": 0.07,
    },
    {
        "sentence1": "A data lake can store raw structured and unstructured information.",
        "sentence2": "The ReLU activation introduces nonlinearity into neural networks.",
        "score": 0.06,
    },
    {
        "sentence1": "A priority queue removes elements according to their assigned priority.",
        "sentence2": "The HTTP protocol enables communication between web clients and servers.",
        "score": 0.05,
    },

    {
        "sentence1": "A model's recall measures how many relevant examples were successfully identified.",
        "sentence2": "A database index can accelerate queries by reducing the amount of data scanned.",
        "score": 0.11,
    },
    {
        "sentence1": "A neural network's learning rate controls the magnitude of optimization updates.",
        "sentence2": "A network switch forwards Ethernet frames according to MAC addresses.",
        "score": 0.05,
    },
    {
        "sentence1": "An HTTP request may contain headers describing metadata about the communication.",
        "sentence2": "A decision tree selects splitting conditions based on feature values.",
        "score": 0.06,
    },
    {
        "sentence1": "A virtual address is translated into a physical address by memory management hardware.",
        "sentence2": "A sentiment classifier predicts whether a text expresses positive or negative sentiment.",
        "score": 0.04,
    },
    {
        "sentence1": "A compiler's lexer identifies tokens such as keywords and identifiers.",
        "sentence2": "A database transaction ensures a collection of operations behaves as a logical unit.",
        "score": 0.06,
    },
    {
        "sentence1": "An encoder-decoder architecture transforms an input representation into an output sequence.",
        "sentence2": "A firewall blocks or permits network traffic according to configured rules.",
        "score": 0.07,
    },
    {
        "sentence1": "A model can overfit when it captures noise specific to the training dataset.",
        "sentence2": "A router forwards packets toward their destination using routing information.",
        "score": 0.05,
    },
    {
        "sentence1": "A cache exploits temporal locality by retaining recently accessed information.",
        "sentence2": "A tokenizer converts text into discrete units for language processing.",
        "score": 0.06,
    },
    {
        "sentence1": "A hash function produces a deterministic output from an input value.",
        "sentence2": "A Transformer represents relationships between tokens using attention.",
        "score": 0.08,
    },
    {
        "sentence1": "A REST API commonly uses HTTP verbs to operate on web resources.",
        "sentence2": "A minimum spanning tree minimizes the total weight needed to connect graph vertices.",
        "score": 0.04,
    },

    {
        "sentence1": "A training dataset contains examples used to optimize machine learning parameters.",
        "sentence2": "A test dataset evaluates a model on examples that were excluded from training.",
        "score": 0.38,
    },
    {
        "sentence1": "Precision and recall evaluate different aspects of information retrieval performance.",
        "sentence2": "Precision measures how many retrieved items are relevant, whereas recall measures how many relevant items were retrieved.",
        "score": 0.94,
    },
    {
        "sentence1": "A stack removes its most recently inserted element first.",
        "sentence2": "A queue removes the element that has been waiting the longest.",
        "score": 0.44,
    },
    {
        "sentence1": "Symmetric cryptography uses the same secret key for encryption and decryption.",
        "sentence2": "Asymmetric cryptography relies on a pair of mathematically related public and private keys.",
        "score": 0.32,
    },
    {
        "sentence1": "TCP establishes a connection before reliably transmitting application data.",
        "sentence2": "UDP sends datagrams without providing TCP-style connection establishment or delivery guarantees.",
        "score": 0.31,
    },
    {
        "sentence1": "A process has its own virtual address space and operating-system resources.",
        "sentence2": "Threads within a process generally share the same memory address space.",
        "score": 0.48,
    },
    {
        "sentence1": "Normalization can reduce redundancy in relational database schemas.",
        "sentence2": "Denormalization intentionally introduces redundancy to improve read performance in some workloads.",
        "score": 0.39,
    },
    {
        "sentence1": "Batch processing collects data and processes it in groups.",
        "sentence2": "Stream processing handles events continuously as they become available.",
        "score": 0.36,
    },
    {
        "sentence1": "Supervised learning uses labeled examples to learn a mapping from inputs to target outputs.",
        "sentence2": "Unsupervised learning attempts to discover structure without explicit target labels.",
        "score": 0.35,
    },
    {
        "sentence1": "Classification predicts discrete categories for input observations.",
        "sentence2": "Regression predicts numerical values that can vary continuously.",
        "score": 0.37,
    },

    {
        "sentence1": "Overfitting is associated with low training error but poor performance on unseen data.",
        "sentence2": "Underfitting occurs when a model cannot adequately capture the underlying patterns in the training data.",
        "score": 0.41,
    },
    {
        "sentence1": "Precision increases when the number of false positive predictions decreases while relevant predictions remain stable.",
        "sentence2": "Recall improves when a classifier identifies a larger fraction of the actual positive instances.",
        "score": 0.46,
    },
    {
        "sentence1": "High-dimensional embeddings can make exhaustive nearest-neighbor search computationally expensive.",
        "sentence2": "Approximate indexing methods trade some exactness for faster similarity retrieval.",
        "score": 0.52,
    },
    {
        "sentence1": "A generative model learns a distribution that can be used to produce new samples.",
        "sentence2": "A discriminative model focuses on distinguishing between classes or predicting labels.",
        "score": 0.35,
    },
    {
        "sentence1": "A tokenizer divides text into tokens before a Transformer processes the sequence.",
        "sentence2": "An embedding model converts text representations into numerical vectors.",
        "score": 0.48,
    },
    {
        "sentence1": "A retriever selects potentially relevant documents from a large collection.",
        "sentence2": "A reranker reorders retrieved candidates according to a more detailed relevance assessment.",
        "score": 0.51,
    },
    {
        "sentence1": "A vector database stores numerical representations for efficient similarity search.",
        "sentence2": "A relational database stores structured records organized according to a predefined schema.",
        "score": 0.29,
    },
    {
        "sentence1": "A model embedding captures information about an input in a dense numerical representation.",
        "sentence2": "A one-hot vector represents a categorical value using mostly zeros and one active position.",
        "score": 0.31,
    },
    {
        "sentence1": "Training modifies model parameters using examples and an optimization objective.",
        "sentence2": "Inference uses an already trained model to generate predictions for new inputs.",
        "score": 0.43,
    },
    {
        "sentence1": "A validation set is used during model development to guide decisions such as hyperparameter selection.",
        "sentence2": "A test set should ideally remain untouched until the final evaluation of the trained system.",
        "score": 0.47,
    },

    {
        "sentence1": "A public key can be distributed openly while the corresponding private key must remain secret.",
        "sentence2": "A symmetric encryption key must generally be shared securely between communicating parties.",
        "score": 0.42,
    },
    {
        "sentence1": "Authentication determines whether a user is who they claim to be.",
        "sentence2": "Authorization determines which actions an authenticated user is allowed to perform.",
        "score": 0.50,
    },
    {
        "sentence1": "Encryption transforms readable information into a protected representation using a cryptographic procedure.",
        "sentence2": "Hashing produces a fixed-length digest that is not intended to be reversed into the original message.",
        "score": 0.39,
    },
    {
        "sentence1": "Horizontal scaling adds more machines or service instances to increase system capacity.",
        "sentence2": "Vertical scaling increases the computational resources available to an existing machine.",
        "score": 0.45,
    },
    {
        "sentence1": "Latency measures the delay associated with completing or transmitting an operation.",
        "sentence2": "Throughput measures the amount of work or data processed during a given period.",
        "score": 0.40,
    },
    {
        "sentence1": "Availability describes how reliably a system remains accessible when users request its services.",
        "sentence2": "Consistency concerns whether different users or replicas observe compatible versions of shared data.",
        "score": 0.38,
    },
    {
        "sentence1": "A message queue stores messages so producers and consumers do not need to operate simultaneously.",
        "sentence2": "A synchronous request requires the caller to wait for the corresponding response.",
        "score": 0.34,
    },
    {
        "sentence1": "Containers share the host operating system kernel while isolating application processes.",
        "sentence2": "Virtual machines typically provide stronger hardware-level isolation by running separate guest operating systems.",
        "score": 0.44,
    },
    {
        "sentence1": "Continuous integration validates code changes through automated builds and tests.",
        "sentence2": "Continuous deployment automatically releases validated changes into production environments.",
        "score": 0.53,
    },
    {
        "sentence1": "Unit testing focuses on isolated components.",
        "sentence2": "Integration testing evaluates interactions between multiple components.",
        "score": 0.52,
    },

    {
        "sentence1": "A convolutional neural network is particularly effective at extracting local spatial features from images.",
        "sentence2": "A recurrent neural network is designed to maintain information across sequential processing steps.",
        "score": 0.36,
    },
    {
        "sentence1": "Transformers model token relationships primarily through attention mechanisms.",
        "sentence2": "Traditional recurrent networks process sequences using recurrent hidden states.",
        "score": 0.39,
    },
    {
        "sentence1": "An LSTM uses gates to regulate information flowing through its memory state.",
        "sentence2": "A convolutional network uses spatial filters to extract localized visual patterns.",
        "score": 0.28,
    },
    {
        "sentence1": "An autoencoder learns to reconstruct its input through an encoded latent representation.",
        "sentence2": "A classifier learns decision boundaries that separate examples belonging to different categories.",
        "score": 0.34,
    },
    {
        "sentence1": "A GAN contains a generator that creates synthetic samples and a discriminator that evaluates their realism.",
        "sentence2": "A decision tree predicts outputs by following feature-based branches from the root toward a leaf.",
        "score": 0.05,
    },
    {
        "sentence1": "Reinforcement learning learns behavior through interaction and reward feedback.",
        "sentence2": "Supervised learning minimizes prediction errors using labeled training examples.",
        "score": 0.39,
    },
    {
        "sentence1": "Clustering groups observations according to similarities within the feature space.",
        "sentence2": "Classification assigns observations to predefined categories using learned decision rules.",
        "score": 0.45,
    },
    {
        "sentence1": "PCA transforms correlated variables into orthogonal principal components.",
        "sentence2": "K-means partitions observations by assigning them to nearby centroids.",
        "score": 0.41,
    },
    {
        "sentence1": "Cosine similarity compares the orientation of two vectors.",
        "sentence2": "Euclidean distance measures the geometric separation between two points.",
        "score": 0.46,
    },
    {
        "sentence1": "A reranker evaluates candidate documents after an initial retrieval stage.",
        "sentence2": "A language model generates text based on the input context and learned parameters.",
        "score": 0.19,
    },
    {
        "sentence1": "Deadlock occurs when multiple processes wait indefinitely for resources held by one another.",
        "sentence2": "A compiler converts high-level source code into a lower-level representation.",
        "score": 0.04,
    },
    {
        "sentence1": "The four conditions for deadlock include mutual exclusion, hold and wait, no preemption, and circular wait.",
        "sentence2": "A neural network uses weighted connections to transform input features.",
        "score": 0.03,
    },
    {
        "sentence1": "Process starvation occurs when a task waits for CPU or other resources for an excessively long period.",
        "sentence2": "A hash function maps input data to a fixed-size output.",
        "score": 0.05,
    },
    {
        "sentence1": "Round-robin scheduling allocates CPU time to processes in rotating time slices.",
        "sentence2": "Gradient descent adjusts parameters to reduce an optimization objective.",
        "score": 0.06,
    },
    {
        "sentence1": "Priority scheduling selects processes according to their assigned priority levels.",
        "sentence2": "A tokenizer divides natural language into smaller processing units.",
        "score": 0.05,
    },
    {
        "sentence1": "Virtual memory allows programs to use an address space larger than the available physical memory.",
        "sentence2": "A convolution applies a learned filter across spatial regions of an image.",
        "score": 0.06,
    },
    {
        "sentence1": "Thrashing occurs when a system spends excessive time moving memory pages rather than executing useful work.",
        "sentence2": "A decision tree selects branches according to feature-based conditions.",
        "score": 0.04,
    },
    {
        "sentence1": "Memory fragmentation can prevent large allocations even when sufficient total free memory exists.",
        "sentence2": "A transformer uses attention to combine information from different tokens.",
        "score": 0.06,
    },
    {
        "sentence1": "A system interrupt signals the processor that an event requires attention.",
        "sentence2": "A relational schema defines tables, attributes, and relationships between data entities.",
        "score": 0.04,
    },
    {
        "sentence1": "DMA allows certain devices to transfer data to memory without requiring the CPU to handle every byte directly.",
        "sentence2": "Cross-entropy measures differences between predicted and target probability distributions.",
        "score": 0.05,
    },

    {
        "sentence1": "A compiler optimization can eliminate computations whose results are never used.",
        "sentence2": "A database query retrieves records that satisfy specified conditions.",
        "score": 0.18,
    },
    {
        "sentence1": "Loop invariant code motion moves computations outside loops when their values remain unchanged.",
        "sentence2": "Caching stores frequently accessed information closer to the component that needs it.",
        "score": 0.22,
    },
    {
        "sentence1": "Function inlining replaces a function call with the function's body during compilation.",
        "sentence2": "A neural network expands its hidden representation before producing an output.",
        "score": 0.09,
    },
    {
        "sentence1": "Garbage collection automatically identifies objects that can no longer be reached by a program.",
        "sentence2": "Reference counting tracks how many active references point to an allocated object.",
        "score": 0.62,
    },
    {
        "sentence1": "Static analysis examines source code without executing the program.",
        "sentence2": "Dynamic analysis observes program behavior while the application is running.",
        "score": 0.42,
    },
    {
        "sentence1": "A linker combines compiled object files and libraries into an executable program.",
        "sentence2": "A loader places an executable into memory and prepares it for execution.",
        "score": 0.57,
    },
    {
        "sentence1": "An assembler translates assembly instructions into machine code.",
        "sentence2": "A compiler translates high-level programming constructs into lower-level representations.",
        "score": 0.55,
    },
    {
        "sentence1": "An interpreter executes instructions incrementally at runtime.",
        "sentence2": "A compiler generally translates an entire program or compilation unit before execution.",
        "score": 0.49,
    },
    {
        "sentence1": "Recursion solves a problem by defining a function in terms of smaller instances of itself.",
        "sentence2": "Iteration repeatedly executes a block of instructions until a termination condition is reached.",
        "score": 0.51,
    },
    {
        "sentence1": "A recursive algorithm requires a base case to terminate correctly.",
        "sentence2": "A loop requires a stopping condition to avoid continuing indefinitely.",
        "score": 0.48,
    },

    {
        "sentence1": "A trie stores strings by organizing characters along paths in a tree-like structure.",
        "sentence2": "A binary search tree organizes keys according to ordering relationships.",
        "score": 0.46,
    },
    {
        "sentence1": "A B-tree is designed to keep large amounts of sorted data efficiently accessible from secondary storage.",
        "sentence2": "A binary heap maintains an ordering property useful for priority-based retrieval.",
        "score": 0.39,
    },
    {
        "sentence1": "A Bloom filter provides probabilistic membership testing using a compact bit array.",
        "sentence2": "A hash table stores key-value pairs for efficient lookup.",
        "score": 0.55,
    },
    {
        "sentence1": "A linked list stores elements in nodes connected through references.",
        "sentence2": "An array stores elements in contiguous indexed memory locations.",
        "score": 0.48,
    },
    {
        "sentence1": "A doubly linked list maintains references to both the previous and next nodes.",
        "sentence2": "A singly linked list stores a reference to the next node.",
        "score": 0.63,
    },
    {
        "sentence1": "A circular buffer reuses storage positions as elements are inserted and removed.",
        "sentence2": "A queue processes elements according to their insertion order.",
        "score": 0.54,
    },
    {
        "sentence1": "A graph may contain cycles and does not necessarily have a hierarchical structure.",
        "sentence2": "A tree is a connected acyclic graph with a hierarchical organization.",
        "score": 0.56,
    },
    {
        "sentence1": "A directed graph assigns a direction to each edge between vertices.",
        "sentence2": "An undirected graph represents relationships where edges do not have an orientation.",
        "score": 0.61,
    },
    {
        "sentence1": "Depth-first search explores one branch deeply before considering alternative branches.",
        "sentence2": "Breadth-first search visits vertices according to their distance from the starting point.",
        "score": 0.58,
    },
    {
        "sentence1": "Topological sorting orders vertices so that dependencies appear before dependent nodes.",
        "sentence2": "Breadth-first traversal explores nodes level by level.",
        "score": 0.32,
    },

    {
        "sentence1": "A REST API is commonly designed around resources identified by URLs.",
        "sentence2": "GraphQL allows clients to specify the structure of the data they want to retrieve.",
        "score": 0.55,
    },
    {
        "sentence1": "GraphQL allows clients to request nested fields in a single query.",
        "sentence2": "SQL retrieves structured records from relational databases.",
        "score": 0.43,
    },
    {
        "sentence1": "WebSockets maintain a persistent communication channel between a client and server.",
        "sentence2": "HTTP traditionally follows a request-response communication model.",
        "score": 0.51,
    },
    {
        "sentence1": "A CDN caches content at geographically distributed edge locations.",
        "sentence2": "A load balancer distributes requests among available application servers.",
        "score": 0.54,
    },
    {
        "sentence1": "DNS caching reduces the need to repeatedly query authoritative name servers.",
        "sentence2": "Browser caching reduces repeated downloads of resources already stored locally.",
        "score": 0.67,
    },
    {
        "sentence1": "ARP maps an IPv4 address to a corresponding MAC address within a local network.",
        "sentence2": "DNS maps domain names to IP addresses.",
        "score": 0.57,
    },
    {
        "sentence1": "DHCP automatically provides devices with network configuration parameters.",
        "sentence2": "DNS resolves human-readable hostnames into network addresses.",
        "score": 0.52,
    },
    {
        "sentence1": "A subnet divides an IP network into smaller logical network segments.",
        "sentence2": "A VLAN separates network traffic into logically isolated broadcast domains.",
        "score": 0.58,
    },
    {
        "sentence1": "NAT modifies network address information as traffic passes between network boundaries.",
        "sentence2": "A proxy server forwards requests on behalf of clients.",
        "score": 0.46,
    },
    {
        "sentence1": "A reverse proxy receives client requests and forwards them to backend servers.",
        "sentence2": "A load balancer distributes traffic among multiple backend instances.",
        "score": 0.64,
    },

    {
        "sentence1": "SQL injection occurs when untrusted input changes the structure of a database query.",
        "sentence2": "Cross-site scripting occurs when malicious code is executed in a user's browser.",
        "score": 0.49,
    },
    {
        "sentence1": "Cross-site request forgery tricks an authenticated browser into performing an unintended action.",
        "sentence2": "Cross-site scripting injects executable content into web pages viewed by users.",
        "score": 0.55,
    },
    {
        "sentence1": "A denial-of-service attack attempts to make a service unavailable to legitimate users.",
        "sentence2": "A brute-force attack repeatedly tries possible credentials to discover a valid password.",
        "score": 0.28,
    },
    {
        "sentence1": "Phishing uses deceptive messages to persuade victims to reveal sensitive information.",
        "sentence2": "Social engineering manipulates people into performing actions that compromise security.",
        "score": 0.72,
    },
    {
        "sentence1": "Multi-factor authentication requires evidence from multiple authentication categories.",
        "sentence2": "Password authentication verifies identity using a secret credential known by the user.",
        "score": 0.56,
    },
    {
        "sentence1": "A salt is added to password-derived hashes to make precomputed attacks more difficult.",
        "sentence2": "Encryption protects data by transforming plaintext into ciphertext.",
        "score": 0.37,
    },
    {
        "sentence1": "A certificate binds a public key to an identity through a trusted certification process.",
        "sentence2": "A digital signature can be verified using the public key associated with the signer.",
        "score": 0.64,
    },
    {
        "sentence1": "Access control lists specify which entities can perform operations on protected resources.",
        "sentence2": "Firewalls specify which network connections should be allowed or blocked.",
        "score": 0.52,
    },
    {
        "sentence1": "Intrusion detection systems monitor activity for signs of malicious behavior.",
        "sentence2": "Firewalls enforce predefined rules for network traffic.",
        "score": 0.55,
    },
    {
        "sentence1": "Malware is software designed to perform harmful or unauthorized actions.",
        "sentence2": "A vulnerability is a weakness that can potentially be exploited by an attacker.",
        "score": 0.48,
    },

    {
        "sentence1": "A data warehouse often uses dimensional models for analytical reporting.",
        "sentence2": "A transactional database is optimized for frequent operational updates.",
        "score": 0.49,
    },
    {
        "sentence1": "A fact table typically contains measurable business events in a dimensional warehouse.",
        "sentence2": "A dimension table provides descriptive attributes used to analyze those events.",
        "score": 0.71,
    },
    {
        "sentence1": "A star schema connects a central fact table directly to several dimension tables.",
        "sentence2": "A snowflake schema further normalizes dimension tables into additional related structures.",
        "score": 0.67,
    },
    {
        "sentence1": "Partitioning divides a large dataset into smaller logical sections.",
        "sentence2": "Sharding distributes partitions across multiple database servers.",
        "score": 0.63,
    },
    {
        "sentence1": "A database transaction should satisfy atomicity, consistency, isolation, and durability.",
        "sentence2": "Distributed consensus allows multiple nodes to agree on a shared decision.",
        "score": 0.21,
    },
    {
        "sentence1": "Eventual consistency allows replicas to temporarily contain different values before converging.",
        "sentence2": "Strong consistency requires reads to reflect an appropriately recent committed state.",
        "score": 0.69,
    },
    {
        "sentence1": "A primary index is typically associated with the ordering or unique identification of records.",
        "sentence2": "A secondary index provides an additional lookup path over one or more attributes.",
        "score": 0.67,
    },
    {
        "sentence1": "Database normalization decomposes relations to reduce redundancy and dependency anomalies.",
        "sentence2": "Database indexing creates additional structures to accelerate retrieval.",
        "score": 0.35,
    },
    {
        "sentence1": "A query optimizer chooses an execution strategy for retrieving requested data.",
        "sentence2": "A compiler optimizer transforms program instructions to improve execution efficiency.",
        "score": 0.46,
    },
    {
        "sentence1": "A database execution plan describes the operations used to evaluate a query.",
        "sentence2": "A workflow scheduler describes dependencies between computational tasks.",
        "score": 0.27,
    },

    {
        "sentence1": "A Docker image contains the filesystem and metadata needed to create containers.",
        "sentence2": "A Docker container is a running instance created from an image.",
        "score": 0.79,
    },
    {
        "sentence1": "Kubernetes manages containerized workloads across a cluster of machines.",
        "sentence2": "Docker packages application dependencies into isolated environments.",
        "score": 0.62,
    },
    {
        "sentence1": "A Kubernetes pod is the smallest deployable unit in the Kubernetes object model.",
        "sentence2": "A Docker container packages an application together with its runtime dependencies.",
        "score": 0.59,
    },
    {
        "sentence1": "A container registry stores and distributes container images.",
        "sentence2": "A package repository stores software packages and their metadata.",
        "score": 0.48,
    },
    {
        "sentence1": "Infrastructure as Code makes infrastructure configuration reproducible through machine-readable definitions.",
        "sentence2": "Version control tracks changes to source code and configuration files.",
        "score": 0.46,
    },
    {
        "sentence1": "CI pipelines automatically validate changes submitted by developers.",
        "sentence2": "CD pipelines automate later stages of software delivery and deployment.",
        "score": 0.69,
    },
    {
        "sentence1": "Blue-green deployment switches production traffic between two environments.",
        "sentence2": "Canary deployment gradually exposes a new version to a subset of users.",
        "score": 0.67,
    },
    {
        "sentence1": "Rolling deployment replaces application instances incrementally.",
        "sentence2": "Blue-green deployment maintains separate old and new environments during a release.",
        "score": 0.63,
    },
    {
        "sentence1": "Horizontal autoscaling changes the number of running service instances according to demand.",
        "sentence2": "Vertical scaling changes the CPU or memory resources assigned to an instance.",
        "score": 0.45,
    },
    {
        "sentence1": "A service mesh manages communication between microservices through dedicated infrastructure components.",
        "sentence2": "An API gateway provides a controlled entry point for external clients accessing backend services.",
        "score": 0.58,
    },

    {
        "sentence1": "Attention weights determine how strongly different input tokens contribute to a representation.",
        "sentence2": "Pooling layers reduce the spatial dimensions of feature maps in convolutional networks.",
        "score": 0.19,
    },
    {
        "sentence1": "Token embeddings represent discrete vocabulary items using continuous vectors.",
        "sentence2": "Positional encodings provide sequence-order information to Transformer architectures.",
        "score": 0.61,
    },
    {
        "sentence1": "A language model estimates the probability of token sequences.",
        "sentence2": "A tokenizer converts text into tokens that can be processed by a model.",
        "score": 0.56,
    },
    {
        "sentence1": "Named entity recognition identifies semantic categories associated with text spans.",
        "sentence2": "Part-of-speech tagging assigns grammatical categories to individual tokens.",
        "score": 0.64,
    },
    {
        "sentence1": "Stemming removes word endings using heuristic rules.",
        "sentence2": "Lemmatization maps words to linguistically meaningful base forms.",
        "score": 0.68,
    },
    {
        "sentence1": "TF-IDF emphasizes terms that are frequent in one document but uncommon across the collection.",
        "sentence2": "Word embeddings represent words as dense vectors learned from contextual or distributional information.",
        "score": 0.39,
    },
    {
        "sentence1": "Cosine similarity is commonly used to compare semantic embedding vectors.",
        "sentence2": "Euclidean distance measures the straight-line distance between numerical points.",
        "score": 0.52,
    },
    {
        "sentence1": "Retrieval-Augmented Generation retrieves external documents before generating a response.",
        "sentence2": "Fine-tuning updates model parameters using examples specific to a target task.",
        "score": 0.43,
    },
    {
        "sentence1": "A reranker scores retrieved candidates using a more computationally expensive relevance model.",
        "sentence2": "An embedding retriever represents queries and documents in a shared vector space.",
        "score": 0.68,
    },
    {
        "sentence1": "Chunking divides long documents into smaller pieces before indexing them for retrieval.",
        "sentence2": "Tokenization converts text into the discrete units consumed by a language model.",
        "score": 0.51,
    },

    {
        "sentence1": "Object detection predicts both the category and spatial location of objects.",
        "sentence2": "Image classification predicts one or more categories for an entire image.",
        "score": 0.66,
    },
    {
        "sentence1": "Semantic segmentation assigns labels independently to image pixels.",
        "sentence2": "Instance segmentation distinguishes individual objects even when they belong to the same category.",
        "score": 0.76,
    },
    {
        "sentence1": "Optical flow estimates apparent motion between consecutive video frames.",
        "sentence2": "Object detection identifies objects and predicts their bounding regions.",
        "score": 0.34,
    },
    {
        "sentence1": "Image normalization adjusts pixel values to improve numerical stability during model training.",
        "sentence2": "Image augmentation creates varied training examples through transformations.",
        "score": 0.57,
    },
    {
        "sentence1": "A convolutional kernel learns weights that detect specific local visual patterns.",
        "sentence2": "A pooling operation reduces the spatial resolution of feature maps.",
        "score": 0.53,
    },
    {
        "sentence1": "Transfer learning starts from parameters learned on a previous dataset or task.",
        "sentence2": "Fine-tuning further optimizes those parameters for a specific downstream objective.",
        "score": 0.72,
    },
    {
        "sentence1": "Dropout randomly disables a subset of neural network units during training.",
        "sentence2": "Batch normalization rescales and shifts activations using statistics computed during training.",
        "score": 0.45,
    },
    {
        "sentence1": "Weight decay penalizes large model parameters during optimization.",
        "sentence2": "Early stopping terminates training when validation performance no longer improves.",
        "score": 0.49,
    },
    {
        "sentence1": "Learning-rate scheduling changes the optimization step size during training.",
        "sentence2": "Gradient clipping limits the magnitude of computed parameter gradients.",
        "score": 0.44,
    },
    {
        "sentence1": "Adam combines gradient information with adaptive estimates of first and second moments.",
        "sentence2": "Stochastic gradient descent updates parameters using gradients computed from training samples or mini-batches.",
        "score": 0.66,
    },

    {
        "sentence1": "A validation set helps select hyperparameters without directly training on those examples.",
        "sentence2": "Cross-validation repeatedly partitions available data to estimate generalization performance.",
        "score": 0.61,
    },
    {
        "sentence1": "A confusion matrix summarizes correct and incorrect predictions across classification classes.",
        "sentence2": "A loss function provides a numerical objective that optimization attempts to minimize.",
        "score": 0.22,
    },
    {
        "sentence1": "Mean absolute error measures the average absolute difference between predictions and targets.",
        "sentence2": "Mean squared error gives greater weight to large prediction errors by squaring them.",
        "score": 0.73,
    },
    {
        "sentence1": "Accuracy measures the fraction of predictions that are correct.",
        "sentence2": "F1 score combines precision and recall using their harmonic mean.",
        "score": 0.55,
    },
    {
        "sentence1": "A calibration curve compares predicted probabilities with observed outcome frequencies.",
        "sentence2": "A ROC curve compares true-positive rates against false-positive rates across thresholds.",
        "score": 0.54,
    },
    {
        "sentence1": "Data leakage occurs when information unavailable at prediction time influences model training.",
        "sentence2": "Overfitting occurs when a model captures patterns that fail to generalize beyond its training examples.",
        "score": 0.57,
    },
    {
        "sentence1": "Class imbalance occurs when some target categories contain substantially more observations than others.",
        "sentence2": "Sampling bias occurs when collected data does not adequately represent the target population.",
        "score": 0.58,
    },
    {
        "sentence1": "Concept drift changes the relationship between features and target outcomes over time.",
        "sentence2": "Data drift changes the distribution of input features observed by a deployed model.",
        "score": 0.76,
    },
    {
        "sentence1": "Model calibration concerns whether predicted confidence values correspond to actual frequencies.",
        "sentence2": "Model accuracy concerns the fraction of predictions that match the correct labels.",
        "score": 0.43,
    },
    {
        "sentence1": "An embedding model maps inputs into a numerical representation space.",
        "sentence2": "A clustering algorithm groups representations according to a chosen similarity criterion.",
        "score": 0.49,
    },
    {
        "sentence1": "A function encapsulates a reusable sequence of operations that can accept inputs and produce outputs.",
        "sentence2": "A variable stores a value that can be referenced during program execution.",
        "score": 0.34,
    },
    {
        "sentence1": "Recursion allows a function to invoke itself while solving progressively smaller instances of a problem.",
        "sentence2": "A loop repeatedly executes instructions until its termination condition becomes true.",
        "score": 0.43,
    },
    {
        "sentence1": "An exception represents an abnormal condition that interrupts the normal flow of program execution.",
        "sentence2": "A compiler optimization transforms code to improve performance without changing its intended behavior.",
        "score": 0.07,
    },
    {
        "sentence1": "Interfaces define operations that implementing classes are expected to provide.",
        "sentence2": "Abstract classes can provide both abstract methods and shared implementation.",
        "score": 0.61,
    },
    {
        "sentence1": "Dependency injection provides an object with its dependencies instead of requiring it to construct them internally.",
        "sentence2": "Factory methods create objects while hiding the details of their concrete construction.",
        "score": 0.48,
    },
    {
        "sentence1": "A software module groups related functionality behind a defined interface.",
        "sentence2": "A database schema describes the organization of stored data.",
        "score": 0.14,
    },
    {
        "sentence1": "Refactoring changes the internal structure of software without intentionally changing its external behavior.",
        "sentence2": "Debugging attempts to identify and correct defects responsible for incorrect program behavior.",
        "score": 0.53,
    },
    {
        "sentence1": "Version control records changes to files so developers can collaborate and recover previous versions.",
        "sentence2": "A backup system creates copies of data that can be restored after loss or corruption.",
        "score": 0.52,
    },
    {
        "sentence1": "An immutable object cannot have its state modified after creation.",
        "sentence2": "A constant represents a value that should not be reassigned after initialization.",
        "score": 0.63,
    },
    {
        "sentence1": "Garbage collection identifies memory that is no longer reachable by the running program.",
        "sentence2": "Manual memory management requires programmers to explicitly allocate and release memory.",
        "score": 0.48,
    },

    # =========================
    # Algorithms
    # =========================

    {
        "sentence1": "Binary search requires the input sequence to be ordered before repeatedly dividing the search interval.",
        "sentence2": "Linear search checks elements sequentially until the desired value is found.",
        "score": 0.48,
    },
    {
        "sentence1": "Heap sort repeatedly extracts elements from a heap to construct a sorted sequence.",
        "sentence2": "Merge sort combines already sorted subarrays to obtain the final ordering.",
        "score": 0.42,
    },
    {
        "sentence1": "Insertion sort builds a sorted portion by inserting each new element into its appropriate position.",
        "sentence2": "Selection sort repeatedly chooses the smallest remaining element and places it into the sorted portion.",
        "score": 0.64,
    },
    {
        "sentence1": "Counting sort uses frequencies of integer values instead of directly comparing elements.",
        "sentence2": "Comparison-based sorting algorithms determine ordering by comparing pairs of elements.",
        "score": 0.41,
    },
    {
        "sentence1": "Floyd-Warshall computes shortest paths between all pairs of vertices using dynamic programming.",
        "sentence2": "Dijkstra's algorithm repeatedly selects the nearest unresolved vertex to compute shortest paths.",
        "score": 0.54,
    },
    {
        "sentence1": "Bellman-Ford can handle graphs containing negative edge weights.",
        "sentence2": "Dijkstra's algorithm assumes edge weights are non-negative.",
        "score": 0.67,
    },
    {
        "sentence1": "Union-Find efficiently maintains connected components while edges are added to a graph.",
        "sentence2": "A priority queue retrieves elements according to their assigned priority.",
        "score": 0.19,
    },
    {
        "sentence1": "Dynamic programming is effective when subproblems overlap and an optimal substructure exists.",
        "sentence2": "Divide and conquer recursively separates a problem into independent or mostly independent subproblems.",
        "score": 0.62,
    },
    {
        "sentence1": "A greedy algorithm commits to locally attractive decisions without generally exploring all alternatives.",
        "sentence2": "Backtracking systematically explores alternatives and reverses choices that cannot lead to valid solutions.",
        "score": 0.43,
    },
    {
        "sentence1": "The traveling salesman problem asks for the shortest tour that visits every specified location and returns to the starting point.",
        "sentence2": "Shortest path algorithms generally seek an optimal route between specified source and destination vertices.",
        "score": 0.61,
    },

    # =========================
    # Data Structures
    # =========================

    {
        "sentence1": "A stack is useful for representing nested function calls and undo operations.",
        "sentence2": "A queue is commonly used to model waiting lines and breadth-first traversal.",
        "score": 0.64,
    },
    {
        "sentence1": "A deque supports insertion and removal from both ends.",
        "sentence2": "A priority queue removes elements according to priority rather than insertion order.",
        "score": 0.56,
    },
    {
        "sentence1": "A balanced binary search tree maintains height constraints to keep search operations efficient.",
        "sentence2": "A hash table provides average constant-time lookup through hashing.",
        "score": 0.37,
    },
    {
        "sentence1": "An AVL tree automatically performs rotations to maintain balance after updates.",
        "sentence2": "A B-tree is optimized for accessing large datasets stored on secondary storage.",
        "score": 0.49,
    },
    {
        "sentence1": "A graph adjacency list stores neighboring vertices for each vertex.",
        "sentence2": "An adjacency matrix represents relationships using a two-dimensional table.",
        "score": 0.76,
    },
    {
        "sentence1": "A trie is especially useful for prefix-based string queries.",
        "sentence2": "A heap is especially useful for repeatedly retrieving minimum or maximum values.",
        "score": 0.24,
    },
    {
        "sentence1": "A sparse matrix stores primarily nonzero values without allocating space for every possible entry.",
        "sentence2": "A dense matrix explicitly represents most positions in a rectangular numerical structure.",
        "score": 0.71,
    },
    {
        "sentence1": "A linked list can insert an element efficiently when the appropriate node reference is already available.",
        "sentence2": "An array provides constant-time indexed access under the usual contiguous storage model.",
        "score": 0.47,
    },
    {
        "sentence1": "A hash collision happens when multiple keys map to the same hash location.",
        "sentence2": "A cache miss occurs when requested information is absent from the cache.",
        "score": 0.26,
    },
    {
        "sentence1": "A circular linked list connects the final node back to the beginning.",
        "sentence2": "A doubly linked list stores references to both neighboring directions.",
        "score": 0.58,
    },

    # =========================
    # Operating Systems
    # =========================

    {
        "sentence1": "A process contains execution state and resources managed by the operating system.",
        "sentence2": "A thread represents an execution path within a process.",
        "score": 0.74,
    },
    {
        "sentence1": "Processes typically have isolated virtual address spaces.",
        "sentence2": "Threads belonging to one process can share its memory space.",
        "score": 0.61,
    },
    {
        "sentence1": "A system call allows user-level software to request privileged operating-system services.",
        "sentence2": "An API allows software components to communicate through defined operations.",
        "score": 0.51,
    },
    {
        "sentence1": "Virtual memory separates the addresses used by programs from physical memory locations.",
        "sentence2": "Caching reduces access time by storing frequently needed information closer to the processor.",
        "score": 0.31,
    },
    {
        "sentence1": "A page fault occurs when a referenced virtual memory page is not currently available in physical memory.",
        "sentence2": "A cache miss occurs when requested information is not present in the cache.",
        "score": 0.49,
    },
    {
        "sentence1": "The scheduler decides which runnable task should receive processor time.",
        "sentence2": "The memory manager controls allocation and translation of memory resources.",
        "score": 0.57,
    },
    {
        "sentence1": "Deadlock prevents a group of processes from progressing because each waits for resources held by another.",
        "sentence2": "Starvation occurs when a task is repeatedly denied access to resources.",
        "score": 0.69,
    },
    {
        "sentence1": "A semaphore can coordinate access to shared resources between concurrent threads.",
        "sentence2": "A mutex provides exclusive ownership of a protected critical section.",
        "score": 0.76,
    },
    {
        "sentence1": "A context switch saves the state of one execution context and restores another.",
        "sentence2": "A function call transfers control to another section of the same running program.",
        "score": 0.38,
    },
    {
        "sentence1": "A kernel runs with elevated privileges and manages core operating-system resources.",
        "sentence2": "A user application normally runs with restricted permissions.",
        "score": 0.42,
    },

    # =========================
    # Networking
    # =========================

    {
        "sentence1": "TCP uses acknowledgments and retransmissions to provide reliable delivery.",
        "sentence2": "UDP provides a lightweight datagram transport without TCP's reliability guarantees.",
        "score": 0.44,
    },
    {
        "sentence1": "IP is responsible for addressing and routing packets across interconnected networks.",
        "sentence2": "TCP manages reliable transport between application endpoints.",
        "score": 0.64,
    },
    {
        "sentence1": "Ethernet defines technologies for transmitting frames over local networks.",
        "sentence2": "IP defines addressing and routing across networks.",
        "score": 0.57,
    },
    {
        "sentence1": "A MAC address identifies a network interface at the data-link layer.",
        "sentence2": "An IP address identifies a network endpoint at the network layer.",
        "score": 0.61,
    },
    {
        "sentence1": "A router separates broadcast domains and forwards packets between networks.",
        "sentence2": "A switch forwards frames between devices within a local network.",
        "score": 0.67,
    },
    {
        "sentence1": "DNS resolves names such as example.org into network addresses.",
        "sentence2": "DHCP automatically assigns network configuration parameters to devices.",
        "score": 0.53,
    },
    {
        "sentence1": "HTTP status codes communicate the result of a web request.",
        "sentence2": "HTTP headers provide metadata associated with requests and responses.",
        "score": 0.67,
    },
    {
        "sentence1": "HTTPS protects HTTP communication using TLS.",
        "sentence2": "SSH provides secure remote access to networked systems.",
        "score": 0.61,
    },
    {
        "sentence1": "Packet switching divides data into packets that can be forwarded independently through a network.",
        "sentence2": "Circuit switching establishes a dedicated communication path between endpoints.",
        "score": 0.48,
    },
    {
        "sentence1": "Network latency represents communication delay.",
        "sentence2": "Network throughput represents the amount of data successfully transferred per unit time.",
        "score": 0.42,
    },

    # =========================
    # Databases
    # =========================

    {
        "sentence1": "A relational database represents information using rows and columns.",
        "sentence2": "A document database stores records as document-oriented structures.",
        "score": 0.65,
    },
    {
        "sentence1": "A primary key uniquely identifies a row within a table.",
        "sentence2": "A foreign key references a key in another table.",
        "score": 0.72,
    },
    {
        "sentence1": "Database normalization reduces redundant representations of the same information.",
        "sentence2": "Database denormalization may duplicate information to reduce query complexity.",
        "score": 0.52,
    },
    {
        "sentence1": "An index creates an additional structure that can accelerate data retrieval.",
        "sentence2": "A transaction defines a logical group of database operations.",
        "score": 0.31,
    },
    {
        "sentence1": "ACID properties describe important guarantees associated with reliable transactions.",
        "sentence2": "CAP describes trade-offs involving consistency, availability, and partition tolerance.",
        "score": 0.49,
    },
    {
        "sentence1": "Database replication creates additional copies of stored information.",
        "sentence2": "Database partitioning divides information into smaller logical segments.",
        "score": 0.64,
    },
    {
        "sentence1": "A query optimizer chooses an efficient execution plan.",
        "sentence2": "A query parser checks whether a database query follows the expected syntax.",
        "score": 0.66,
    },
    {
        "sentence1": "A materialized view stores query results so they can be reused.",
        "sentence2": "A cache stores frequently requested information to reduce repeated computation or retrieval.",
        "score": 0.69,
    },
    {
        "sentence1": "A database trigger executes automatically when specified database events occur.",
        "sentence2": "A scheduled job executes according to a predefined time or scheduling rule.",
        "score": 0.45,
    },
    {
        "sentence1": "A stored procedure contains reusable SQL logic that can be invoked by clients.",
        "sentence2": "A database view represents a query-defined virtual table.",
        "score": 0.62,
    },

    # =========================
    # Data Engineering
    # =========================

    {
        "sentence1": "ETL transforms data before loading it into the destination system.",
        "sentence2": "ELT loads raw data first and performs transformations within the destination platform.",
        "score": 0.79,
    },
    {
        "sentence1": "Batch pipelines process accumulated records in discrete execution intervals.",
        "sentence2": "Streaming pipelines process incoming events continuously.",
        "score": 0.69,
    },
    {
        "sentence1": "A data lake can store raw structured and unstructured information.",
        "sentence2": "A data warehouse generally stores curated data optimized for analytics.",
        "score": 0.71,
    },
    {
        "sentence1": "Apache Spark distributes data processing across multiple compute nodes.",
        "sentence2": "Apache Kafka distributes event streams across brokers.",
        "score": 0.53,
    },
    {
        "sentence1": "Airflow schedules and orchestrates dependencies between workflow tasks.",
        "sentence2": "Kafka transports streams of records between producers and consumers.",
        "score": 0.36,
    },
    {
        "sentence1": "Data partitioning divides datasets according to selected keys or ranges.",
        "sentence2": "Data compression reduces the storage required to represent information.",
        "score": 0.33,
    },
    {
        "sentence1": "Schema evolution describes controlled changes to the structure of stored or transmitted data.",
        "sentence2": "Version control tracks changes to software artifacts over time.",
        "score": 0.36,
    },
    {
        "sentence1": "Data lineage describes where data originated and how it changed across processing stages.",
        "sentence2": "Data provenance records information about the origin and transformation history of data.",
        "score": 0.91,
    },
    {
        "sentence1": "A data catalog helps users discover datasets and understand their metadata.",
        "sentence2": "A database index helps queries locate records efficiently.",
        "score": 0.22,
    },
    {
        "sentence1": "A streaming window groups events according to temporal boundaries for analysis.",
        "sentence2": "A batch job groups records according to a scheduled execution interval.",
        "score": 0.48,
    },

    # =========================
    # Cloud & Distributed Systems
    # =========================

    {
        "sentence1": "Cloud computing provides on-demand access to scalable computing resources.",
        "sentence2": "Distributed computing divides computational work across multiple machines.",
        "score": 0.68,
    },
    {
        "sentence1": "A virtual machine provides an isolated environment containing a guest operating system.",
        "sentence2": "A container isolates application processes while sharing the host kernel.",
        "score": 0.71,
    },
    {
        "sentence1": "Horizontal scaling increases capacity by adding additional service instances.",
        "sentence2": "Vertical scaling increases the resources assigned to an existing instance.",
        "score": 0.56,
    },
    {
        "sentence1": "A load balancer distributes requests across multiple backend instances.",
        "sentence2": "A scheduler assigns computational tasks to available resources.",
        "score": 0.49,
    },
    {
        "sentence1": "Service discovery allows distributed components to locate available services.",
        "sentence2": "DNS allows clients to resolve names into network addresses.",
        "score": 0.58,
    },
    {
        "sentence1": "Consensus algorithms allow distributed nodes to agree on a shared value.",
        "sentence2": "Replication maintains multiple copies of data across different machines.",
        "score": 0.57,
    },
    {
        "sentence1": "Leader election selects one node to coordinate certain distributed operations.",
        "sentence2": "Load balancing distributes work among available nodes.",
        "score": 0.29,
    },
    {
        "sentence1": "Fault tolerance allows a system to continue operating despite certain component failures.",
        "sentence2": "High availability aims to minimize the time a service is inaccessible.",
        "score": 0.73,
    },
    {
        "sentence1": "Eventual consistency permits temporary differences between replicas before they converge.",
        "sentence2": "Replication distributes copies of data across multiple nodes.",
        "score": 0.62,
    },
    {
        "sentence1": "A distributed system may experience network partitions that prevent some nodes from communicating.",
        "sentence2": "A single-machine application generally does not require network communication between its internal components.",
        "score": 0.31,
    },

    # =========================
    # Security
    # =========================

    {
        "sentence1": "Authentication verifies the identity of an entity.",
        "sentence2": "Authorization determines which operations that entity can perform.",
        "score": 0.67,
    },
    {
        "sentence1": "Encryption protects information by transforming plaintext into ciphertext.",
        "sentence2": "Authentication verifies the identity of a communicating party.",
        "score": 0.28,
    },
    {
        "sentence1": "Hash functions produce fixed-length representations of input data.",
        "sentence2": "Encryption is designed to allow authorized parties to recover the original plaintext.",
        "score": 0.42,
    },
    {
        "sentence1": "A brute-force attack systematically attempts many possible passwords.",
        "sentence2": "A dictionary attack tries credentials derived from a predefined collection of likely words.",
        "score": 0.76,
    },
    {
        "sentence1": "Phishing commonly uses deceptive communication to obtain sensitive information.",
        "sentence2": "Malware is software intentionally designed to perform harmful or unauthorized actions.",
        "score": 0.54,
    },
    {
        "sentence1": "A firewall controls network traffic according to configured rules.",
        "sentence2": "An antivirus application detects or removes malicious software.",
        "score": 0.51,
    },
    {
        "sentence1": "A vulnerability is a weakness that can potentially be exploited.",
        "sentence2": "A threat is a potential source of harm to a system.",
        "score": 0.64,
    },
    {
        "sentence1": "A security patch modifies software to address known vulnerabilities.",
        "sentence2": "A software update may introduce new functionality or improve existing behavior.",
        "score": 0.59,
    },
    {
        "sentence1": "Least privilege limits users and processes to the permissions they actually require.",
        "sentence2": "Role-based access control assigns permissions according to organizational roles.",
        "score": 0.68,
    },
    {
        "sentence1": "Zero-trust security assumes that network location alone should not imply trust.",
        "sentence2": "Traditional perimeter security often treats internal network locations as more trusted than external ones.",
        "score": 0.61,
    },

    # =========================
    # Machine Learning
    # =========================

    {
        "sentence1": "Linear regression predicts continuous numerical outcomes.",
        "sentence2": "Logistic regression commonly predicts probabilities for categorical outcomes.",
        "score": 0.68,
    },
    {
        "sentence1": "Decision trees recursively partition data according to feature-based conditions.",
        "sentence2": "Random forests combine predictions from multiple decision trees.",
        "score": 0.79,
    },
    {
        "sentence1": "Bagging trains multiple models using resampled versions of the training dataset.",
        "sentence2": "Boosting builds models sequentially to emphasize examples that previous models handled poorly.",
        "score": 0.72,
    },
    {
        "sentence1": "Support vector machines seek a decision boundary with a large margin between classes.",
        "sentence2": "Logistic regression estimates class probabilities using a linear decision function.",
        "score": 0.57,
    },
    {
        "sentence1": "K-means repeatedly updates cluster assignments and centroid positions.",
        "sentence2": "Hierarchical clustering builds a nested structure of groups.",
        "score": 0.66,
    },
    {
        "sentence1": "Anomaly detection identifies observations that deviate significantly from expected patterns.",
        "sentence2": "Classification assigns observations to known target categories.",
        "score": 0.42,
    },
    {
        "sentence1": "Feature selection chooses a subset of variables for model training.",
        "sentence2": "Feature extraction transforms existing variables into a different representation.",
        "score": 0.65,
    },
    {
        "sentence1": "Regularization adds a penalty that discourages overly complex model parameters.",
        "sentence2": "Early stopping limits training based on validation performance.",
        "score": 0.58,
    },
    {
        "sentence1": "Cross-validation repeatedly trains and evaluates models on different partitions of the dataset.",
        "sentence2": "Bootstrapping creates samples by repeatedly drawing observations with replacement.",
        "score": 0.52,
    },
    {
        "sentence1": "Hyperparameters are configuration values chosen outside the normal parameter optimization process.",
        "sentence2": "Model parameters are values learned directly from training data.",
        "score": 0.48,
    },

    # =========================
    # Deep Learning
    # =========================

    {
        "sentence1": "Backpropagation computes gradients of the loss with respect to neural network parameters.",
        "sentence2": "Gradient descent uses gradients to update neural network parameters.",
        "score": 0.77,
    },
    {
        "sentence1": "Batch normalization normalizes activations using statistics derived from training batches.",
        "sentence2": "Layer normalization normalizes activations across features within individual examples.",
        "score": 0.73,
    },
    {
        "sentence1": "Dropout randomly removes neural activations during training.",
        "sentence2": "Weight decay discourages large parameter values during optimization.",
        "score": 0.42,
    },
    {
        "sentence1": "ReLU introduces nonlinear behavior by suppressing negative inputs.",
        "sentence2": "Sigmoid maps scalar inputs into values between zero and one.",
        "score": 0.57,
    },
    {
        "sentence1": "Softmax converts a vector of logits into normalized class probabilities.",
        "sentence2": "Sigmoid independently maps each input value into a bounded interval.",
        "score": 0.61,
    },
    {
        "sentence1": "Residual connections allow a network layer to receive information through a shortcut path.",
        "sentence2": "Skip connections can help optimization in very deep neural architectures.",
        "score": 0.88,
    },
    {
        "sentence1": "An encoder transforms input information into an internal representation.",
        "sentence2": "A decoder transforms an internal representation into an output.",
        "score": 0.65,
    },
    {
        "sentence1": "An LSTM maintains information through gated recurrent states.",
        "sentence2": "A GRU uses update and reset gates to control recurrent information flow.",
        "score": 0.77,
    },
    {
        "sentence1": "A Transformer encoder processes input tokens using self-attention and feed-forward layers.",
        "sentence2": "A Transformer decoder can generate output tokens autoregressively.",
        "score": 0.76,
    },
    {
        "sentence1": "Positional information is necessary because self-attention alone does not inherently encode token order.",
        "sentence2": "Recurrent networks naturally process tokens according to sequential recurrence.",
        "score": 0.44,
    },

    # =========================
    # NLP
    # =========================

    {
        "sentence1": "Tokenization converts raw text into smaller units suitable for language processing.",
        "sentence2": "Sentence segmentation divides a document into individual sentences.",
        "score": 0.68,
    },
    {
        "sentence1": "Stopword removal eliminates frequently occurring words that may contribute little to certain retrieval tasks.",
        "sentence2": "Stemming reduces words to shorter forms by removing morphological endings.",
        "score": 0.57,
    },
    {
        "sentence1": "Word embeddings represent tokens using dense vectors.",
        "sentence2": "TF-IDF represents documents using sparse weighted term features.",
        "score": 0.46,
    },
    {
        "sentence1": "Semantic similarity estimates how closely two pieces of text are related in meaning.",
        "sentence2": "Lexical similarity measures overlap between the actual words used in two texts.",
        "score": 0.67,
    },
    {
        "sentence1": "Question answering systems may retrieve relevant passages before producing an answer.",
        "sentence2": "Text classification assigns predefined labels to documents or text segments.",
        "score": 0.35,
    },
    {
        "sentence1": "Machine translation generates text in a target language based on source-language input.",
        "sentence2": "Text summarization produces a shorter representation of a source document.",
        "score": 0.54,
    },
    {
        "sentence1": "Named entity recognition identifies spans corresponding to semantic entity types.",
        "sentence2": "Relation extraction identifies semantic relationships between entities in text.",
        "score": 0.72,
    },
    {
        "sentence1": "Sentiment analysis determines whether text expresses positive, negative, or neutral attitudes.",
        "sentence2": "Emotion classification attempts to identify categories such as anger, joy, fear, or sadness.",
        "score": 0.71,
    },
    {
        "sentence1": "Language modeling estimates probabilities over sequences of tokens.",
        "sentence2": "Text generation produces new sequences according to a learned language distribution.",
        "score": 0.79,
    },
    {
        "sentence1": "Contextual embeddings can assign different vector representations to the same word depending on surrounding text.",
        "sentence2": "Static word embeddings generally assign one learned vector to each vocabulary item.",
        "score": 0.69,
    },

    # =========================
    # RAG & Embeddings
    # =========================

    {
        "sentence1": "Embedding models transform text into numerical vectors that encode semantic information.",
        "sentence2": "Vector databases store embeddings to support similarity-based retrieval.",
        "score": 0.76,
    },
    {
        "sentence1": "Dense retrieval represents queries and documents as vectors.",
        "sentence2": "Sparse retrieval can represent documents using term-based weighting schemes.",
        "score": 0.59,
    },
    {
        "sentence1": "Cosine similarity compares vectors based on their angular orientation.",
        "sentence2": "Dot product similarity measures the sum of pairwise coordinate products.",
        "score": 0.63,
    },
    {
        "sentence1": "Approximate nearest neighbor algorithms trade exactness for faster vector retrieval.",
        "sentence2": "Exact nearest-neighbor search compares a query against every candidate.",
        "score": 0.68,
    },
    {
        "sentence1": "Chunking affects retrieval quality because overly large chunks may contain irrelevant information.",
        "sentence2": "Small chunks can improve retrieval precision but may lose important surrounding context.",
        "score": 0.78,
    },
    {
        "sentence1": "A reranker evaluates retrieved candidates using a more detailed relevance function.",
        "sentence2": "A retriever identifies candidate documents from a larger corpus.",
        "score": 0.82,
    },
    {
        "sentence1": "Query expansion adds related terms or concepts to improve information retrieval.",
        "sentence2": "Query rewriting changes the formulation of a search request to improve retrieval.",
        "score": 0.79,
    },
    {
        "sentence1": "Grounded generation produces answers based on retrieved evidence.",
        "sentence2": "Hallucination occurs when a model produces unsupported or fabricated information.",
        "score": 0.46,
    },
    {
        "sentence1": "Metadata filtering can restrict retrieval to documents satisfying specific attributes.",
        "sentence2": "Semantic similarity ranks documents according to their vector representations.",
        "score": 0.52,
    },
    {
        "sentence1": "Hybrid retrieval combines lexical matching with semantic vector search.",
        "sentence2": "Ensemble learning combines predictions from multiple machine learning models.",
        "score": 0.35,
    },

    # =========================
    # Computer Vision
    # =========================

    {
        "sentence1": "Image classification predicts categories for an entire image.",
        "sentence2": "Object detection identifies multiple objects and their locations within an image.",
        "score": 0.76,
    },
    {
        "sentence1": "Object detection commonly represents predicted object locations using bounding boxes.",
        "sentence2": "Semantic segmentation represents predictions as dense pixel-level labels.",
        "score": 0.71,
    },
    {
        "sentence1": "OCR converts text appearing in images into machine-readable strings.",
        "sentence2": "Speech recognition converts spoken audio into textual representations.",
        "score": 0.61,
    },
    {
        "sentence1": "Image denoising attempts to remove unwanted noise while preserving useful visual information.",
        "sentence2": "Image compression reduces the storage or transmission size of visual data.",
        "score": 0.48,
    },
    {
        "sentence1": "Edge detection identifies locations of rapid intensity changes in an image.",
        "sentence2": "Object detection identifies semantic objects and their spatial locations.",
        "score": 0.39,
    },
    {
        "sentence1": "Image resizing changes the spatial dimensions of an image.",
        "sentence2": "Image normalization changes the numerical scale of pixel values.",
        "score": 0.47,
    },
    {
        "sentence1": "Data augmentation can expose a vision model to rotations and other transformed examples.",
        "sentence2": "Transfer learning initializes a model using knowledge learned from another dataset.",
        "score": 0.43,
    },
    {
        "sentence1": "A feature map records activations produced by convolutional filters.",
        "sentence2": "A bounding box represents the estimated spatial extent of an detected object.",
        "score": 0.32,
    },
    {
        "sentence1": "Intersection over Union measures overlap between predicted and reference bounding regions.",
        "sentence2": "Accuracy measures the proportion of correct predictions.",
        "score": 0.17,
    },
    {
        "sentence1": "Non-maximum suppression removes redundant overlapping object detections.",
        "sentence2": "Pooling reduces the spatial resolution of convolutional feature maps.",
        "score": 0.39,
    },

    # =========================
    # Software Architecture
    # =========================

    {
        "sentence1": "Microservices divide application functionality into independently deployable services.",
        "sentence2": "A monolithic application is typically deployed as a single unit.",
        "score": 0.69,
    },
    {
        "sentence1": "An API gateway provides a controlled entry point to backend services.",
        "sentence2": "A reverse proxy forwards incoming requests to backend servers.",
        "score": 0.74,
    },
    {
        "sentence1": "Message brokers facilitate asynchronous communication between distributed components.",
        "sentence2": "REST APIs commonly use synchronous request-response interactions.",
        "score": 0.48,
    },
    {
        "sentence1": "Circuit breakers prevent repeated requests to an unhealthy downstream service.",
        "sentence2": "Retry mechanisms attempt failed operations again.",
        "score": 0.61,
    },
    {
        "sentence1": "Idempotent operations can safely be repeated without producing additional unintended effects.",
        "sentence2": "Caching can prevent repeated execution of identical expensive operations.",
        "score": 0.53,
    },
    {
        "sentence1": "A service registry records the locations of available service instances.",
        "sentence2": "A configuration server centralizes application configuration values.",
        "score": 0.47,
    },
    {
        "sentence1": "Distributed tracing follows a request across multiple services.",
        "sentence2": "Application logging records events generated by software components.",
        "score": 0.59,
    },
    {
        "sentence1": "Metrics provide numerical measurements describing system behavior.",
        "sentence2": "Logs provide detailed records of events occurring during execution.",
        "score": 0.62,
    },
    {
        "sentence1": "Observability combines telemetry signals to help engineers understand internal system behavior.",
        "sentence2": "Monitoring tracks predefined indicators and alerts when thresholds are exceeded.",
        "score": 0.72,
    },
    {
        "sentence1": "A health check determines whether a service instance is functioning sufficiently to receive traffic.",
        "sentence2": "A unit test checks whether a specific software component behaves according to expectations.",
        "score": 0.31,
    },

    # =========================
    # Mixed Hard Negatives
    # =========================

    {
        "sentence1": "Gradient descent minimizes an objective function by iteratively updating model parameters.",
        "sentence2": "Shortest path algorithms minimize accumulated edge costs in graphs.",
        "score": 0.21,
    },
    {
        "sentence1": "A neural network learns parameters from training examples.",
        "sentence2": "A compiler learns no parameters and instead applies deterministic translation rules.",
        "score": 0.14,
    },
    {
        "sentence1": "A database query retrieves information according to specified conditions.",
        "sentence2": "A search engine retrieves documents according to relevance estimates.",
        "score": 0.56,
    },
    {
        "sentence1": "A cache reduces repeated access to slower storage or computation.",
        "sentence2": "A database index reduces the amount of data that must be examined during some queries.",
        "score": 0.61,
    },
    {
        "sentence1": "A scheduler determines when tasks execute.",
        "sentence2": "A load balancer determines which server handles a request.",
        "score": 0.43,
    },
    {
        "sentence1": "A tokenizer converts text into discrete units.",
        "sentence2": "A parser converts tokens into a structured representation according to grammar.",
        "score": 0.64,
    },
    {
        "sentence1": "A compiler parser analyzes whether source tokens follow grammatical rules.",
        "sentence2": "A natural language parser analyzes the syntactic structure of human language.",
        "score": 0.68,
    },
    {
        "sentence1": "A vector database retrieves items according to numerical similarity.",
        "sentence2": "A relational database retrieves rows according to structured query conditions.",
        "score": 0.48,
    },
    {
        "sentence1": "A machine learning model predicts outcomes from input features.",
        "sentence2": "A rule-based system determines outcomes using explicitly programmed conditions.",
        "score": 0.57,
    },
    {
        "sentence1": "An optimizer searches for parameter values that improve an objective.",
        "sentence2": "A scheduler searches for tasks that should receive computational resources.",
        "score": 0.29,
    },

]

df = pd.DataFrame(data)

df.to_csv("English_semantic_similarity_dataset.csv", index=False, encoding="utf-8")

print(df)
print("\nDataset saved as 'English_semantic_similarity_dataset.csv'")
# Out:
#                                              sentence1  \
# 0    Transformer architectures rely on self-attenti...
# 1    Gradient checkpointing reduces GPU memory cons...
# 2    Approximate nearest neighbor search significan...
# 3    Normalization layers stabilize optimization by...
# 4    Dynamic programming decomposes optimization pr...
# ..                                                 ...
# 564     A tokenizer converts text into discrete units.
# 565  A compiler parser analyzes whether source toke...
# 566  A vector database retrieves items according to...
# 567  A machine learning model predicts outcomes fro...
# 568  An optimizer searches for parameter values tha...
#
#                                              sentence2  score
# 0    Self-attention enables Transformer models to l...   0.96
# 1    Caching every intermediate activation increase...   0.31
# 2    Vector databases commonly employ approximate i...   0.94
# ...

# %%
arabic_data = [

    {
        "sentence1": "تستخدم الشبكات العصبية طبقات متعددة لتحويل المدخلات إلى تمثيلات أكثر تعقيدًا.",
        "sentence2": "تعتمد خوارزميات البحث الثنائي على تقسيم مساحة البحث إلى أجزاء أصغر.",
        "score": 0.08,
    },
    {
        "sentence1": "تقوم خوارزمية الانحدار التدريجي بتحديث معاملات النموذج بهدف تقليل دالة الخسارة.",
        "sentence2": "يتم استخدام أشجار القرار لتقسيم البيانات بناءً على شروط مرتبطة بالخصائص.",
        "score": 0.21,
    },
    {
        "sentence1": "تستخدم آلية الانتباه الذاتي العلاقات بين الكلمات لبناء تمثيل سياقي للنص.",
        "sentence2": "يسمح الانتباه الذاتي للنموذج بالتركيز على أجزاء مختلفة من الجملة عند معالجة كل كلمة.",
        "score": 0.94,
    },
    {
        "sentence1": "تعمل قواعد البيانات العلائقية على تنظيم المعلومات داخل جداول مترابطة.",
        "sentence2": "تخزن قواعد بيانات المستندات البيانات في هياكل تشبه المستندات بدلاً من الجداول التقليدية.",
        "score": 0.65,
    },
    {
        "sentence1": "تستخدم خوارزمية ديكسترا لإيجاد أقصر المسارات في الرسوم البيانية ذات الأوزان غير السالبة.",
        "sentence2": "تستخدم خوارزمية التجميع العنقودي لتقسيم البيانات إلى مجموعات متشابهة.",
        "score": 0.18,
    },
    {
        "sentence1": "يساعد التخزين المؤقت على تقليل الزمن اللازم للوصول إلى البيانات المتكررة الاستخدام.",
        "sentence2": "تعمل الفهارس في قواعد البيانات على تسريع الوصول إلى السجلات المطلوبة.",
        "score": 0.67,
    },
    {
        "sentence1": "يحول نموذج التضمين الكلمات أو الجمل إلى متجهات رقمية.",
        "sentence2": "تمثل نماذج التضمين النصوص في مساحة عددية تسمح بمقارنة المعاني.",
        "score": 0.96,
    },
    {
        "sentence1": "تستخدم خوارزمية التجميع K-Means مراكز المجموعات لتقسيم البيانات.",
        "sentence2": "تستخدم خوارزمية الانحدار الخطي خطًا للتنبؤ بالقيم العددية.",
        "score": 0.19,
    },
    {
        "sentence1": "يسمح التعلم الاتحادي بتدريب النماذج عبر أجهزة متعددة دون إرسال البيانات الخام إلى خادم مركزي.",
        "sentence2": "يعتمد التعلم الاتحادي على مشاركة تحديثات النموذج بدلاً من مشاركة البيانات الأصلية.",
        "score": 0.95,
    },
    {
        "sentence1": "تستخدم أنظمة التشغيل جدولة العمليات لتحديد العملية التي ستحصل على المعالج.",
        "sentence2": "تستخدم الشبكات بروتوكول DNS لتحويل أسماء النطاقات إلى عناوين IP.",
        "score": 0.05,
    },

    {
        "sentence1": "يحدث الاختناق في الذاكرة عندما يقضي النظام وقتًا كبيرًا في نقل صفحات الذاكرة.",
        "sentence2": "يحدث الاختناق في الشبكة عندما يكون معدل وصول البيانات أعلى من قدرة النظام على معالجتها.",
        "score": 0.57,
    },
    {
        "sentence1": "يحدث الجمود عندما تنتظر عدة عمليات موارد محتجزة بواسطة عمليات أخرى.",
        "sentence2": "يحدث التجويع عندما لا تحصل عملية معينة على الموارد لفترة طويلة.",
        "score": 0.72,
    },
    {
        "sentence1": "تستخدم أنظمة التشغيل الذاكرة الافتراضية لإعطاء البرامج مساحة عناوين أكبر من الذاكرة الفعلية.",
        "sentence2": "تستخدم الشبكات الافتراضية لتقسيم الشبكة إلى شبكات منطقية مستقلة.",
        "score": 0.31,
    },
    {
        "sentence1": "يسمح تعدد الخيوط بتنفيذ أكثر من مسار برمجي داخل العملية نفسها.",
        "sentence2": "تسمح العمليات المتعددة بتنفيذ برامج مستقلة داخل نظام التشغيل.",
        "score": 0.69,
    },
    {
        "sentence1": "تقوم وحدة المعالجة المركزية بتنفيذ التعليمات البرمجية.",
        "sentence2": "تقوم قاعدة البيانات بتخزين واسترجاع المعلومات المنظمة.",
        "score": 0.04,
    },

    {
        "sentence1": "تستخدم خوارزمية البحث الخطي المرور على العناصر بالتتابع حتى العثور على العنصر المطلوب.",
        "sentence2": "يستخدم البحث الثنائي ترتيب العناصر لتقليل مساحة البحث في كل خطوة.",
        "score": 0.59,
    },
    {
        "sentence1": "تعتمد خوارزمية Merge Sort على تقسيم البيانات ثم دمج الأجزاء المرتبة.",
        "sentence2": "تعتمد خوارزمية Quick Sort على اختيار عنصر محوري وتقسيم البيانات حوله.",
        "score": 0.71,
    },
    {
        "sentence1": "تستخدم خوارزمية Heap Sort بنية heap لترتيب العناصر.",
        "sentence2": "تستخدم خوارزمية BFS طابورًا لاستكشاف العقد على مستويات متتالية.",
        "score": 0.29,
    },
    {
        "sentence1": "تستخدم خوارزمية DFS التراجع لاستكشاف مسار عميق قبل الانتقال إلى مسار آخر.",
        "sentence2": "تستكشف خوارزمية BFS العقد القريبة من نقطة البداية قبل الانتقال إلى المستويات الأبعد.",
        "score": 0.76,
    },
    {
        "sentence1": "تستخدم البرمجة الديناميكية نتائج المسائل الفرعية لتجنب إعادة الحساب.",
        "sentence2": "تستخدم البرمجة العودية استدعاءات متكررة لحل نسخ أصغر من المشكلة.",
        "score": 0.63,
    },

    {
        "sentence1": "تخزن المصفوفة العناصر عادةً في مواقع متجاورة في الذاكرة.",
        "sentence2": "تخزن القائمة المرتبطة العناصر داخل عقد متصلة بالمراجع.",
        "score": 0.68,
    },
    {
        "sentence1": "تعمل بنية المكدس وفق مبدأ آخر عنصر يدخل هو أول عنصر يخرج.",
        "sentence2": "تعمل بنية الطابور وفق مبدأ أول عنصر يدخل هو أول عنصر يخرج.",
        "score": 0.74,
    },
    {
        "sentence1": "تسمح بنية Deque بإضافة وحذف العناصر من الطرفين.",
        "sentence2": "تسمح بنية Stack بإضافة وحذف العناصر من طرف واحد.",
        "score": 0.72,
    },
    {
        "sentence1": "تستخدم جداول التجزئة دالة Hash للوصول السريع إلى القيم.",
        "sentence2": "تستخدم الأشجار الثنائية علاقات ترتيب بين العقد لتسهيل عمليات البحث.",
        "score": 0.38,
    },
    {
        "sentence1": "تخزن شجرة Trie الكلمات من خلال مسارات تمثل الأحرف.",
        "sentence2": "تستخدم شجرة Heap لترتيب العناصر حسب الأولوية.",
        "score": 0.24,
    },

    {
        "sentence1": "يستخدم TCP آليات التأكيد وإعادة الإرسال لتوفير نقل موثوق للبيانات.",
        "sentence2": "يوفر UDP نقلًا سريعًا وخفيفًا دون ضمانات TCP الخاصة بالموثوقية.",
        "score": 0.73,
    },
    {
        "sentence1": "يستخدم بروتوكول IP عناوين الشبكة لتوجيه الحزم بين الأجهزة.",
        "sentence2": "يستخدم بروتوكول TCP لضمان وصول البيانات بالترتيب الصحيح.",
        "score": 0.61,
    },
    {
        "sentence1": "يحول DNS أسماء المواقع إلى عناوين IP.",
        "sentence2": "يوزع DHCP إعدادات الشبكة تلقائيًا على الأجهزة.",
        "score": 0.59,
    },
    {
        "sentence1": "يقوم الراوتر بتوجيه الحزم بين الشبكات المختلفة.",
        "sentence2": "يقوم السويتش بتمرير الإطارات بين الأجهزة داخل الشبكة المحلية.",
        "score": 0.73,
    },
    {
        "sentence1": "يمثل عنوان MAC هوية واجهة الشبكة على مستوى طبقة ربط البيانات.",
        "sentence2": "يمثل عنوان IP عنوان الجهاز على مستوى طبقة الشبكة.",
        "score": 0.68,
    },

    {
        "sentence1": "يستخدم HTTPS بروتوكول TLS لحماية الاتصال بين العميل والخادم.",
        "sentence2": "يستخدم SSH لإنشاء اتصال آمن وإدارة الأنظمة عن بعد.",
        "score": 0.69,
    },
    {
        "sentence1": "تستخدم شبكات CDN خوادم موزعة جغرافيًا لتقليل زمن تحميل المحتوى.",
        "sentence2": "تستخدم موازنات الحمل عدة خوادم لتوزيع طلبات المستخدمين.",
        "score": 0.58,
    },
    {
        "sentence1": "تقيس Latency مقدار التأخير الذي يحدث أثناء انتقال البيانات.",
        "sentence2": "يقيس Throughput كمية البيانات التي يمكن نقلها خلال فترة زمنية معينة.",
        "score": 0.54,
    },
    {
        "sentence1": "يقوم NAT بتعديل معلومات العناوين أثناء مرور الحزم بين الشبكات.",
        "sentence2": "يقوم DNS بتحويل أسماء النطاقات إلى عناوين الشبكة.",
        "score": 0.27,
    },
    {
        "sentence1": "يستخدم WebSocket قناة اتصال مستمرة بين العميل والخادم.",
        "sentence2": "يعتمد HTTP التقليدي على نموذج الطلب والاستجابة.",
        "score": 0.63,
    },

    {
        "sentence1": "تقوم المصادقة بالتحقق من هوية المستخدم.",
        "sentence2": "تحدد الصلاحيات العمليات التي يسمح للمستخدم بتنفيذها.",
        "score": 0.71,
    },
    {
        "sentence1": "يقوم التشفير بتحويل النص الواضح إلى نص مشفر لحماية المعلومات.",
        "sentence2": "تقوم دوال التجزئة بتحويل البيانات إلى قيم ثابتة الطول.",
        "score": 0.57,
    },
    {
        "sentence1": "يستخدم هجوم القوة الغاشمة عددًا كبيرًا من محاولات كلمات المرور.",
        "sentence2": "يستخدم هجوم التصيد رسائل خادعة للحصول على معلومات حساسة.",
        "score": 0.35,
    },
    {
        "sentence1": "تستخدم المصادقة متعددة العوامل أكثر من نوع واحد من أدلة الهوية.",
        "sentence2": "تستخدم المصادقة بكلمة المرور سرًا يعرفه المستخدم للتحقق من هويته.",
        "score": 0.66,
    },
    {
        "sentence1": "تمنع جدران الحماية الاتصالات التي تخالف قواعد الأمان المحددة.",
        "sentence2": "تقوم برامج مكافحة الفيروسات باكتشاف البرمجيات الخبيثة وإزالتها.",
        "score": 0.55,
    },

    {
        "sentence1": "يحدث SQL Injection عندما يتمكن إدخال المستخدم من تغيير بنية استعلام قاعدة البيانات.",
        "sentence2": "يحدث XSS عندما يتم تنفيذ كود ضار داخل متصفح المستخدم.",
        "score": 0.59,
    },
    {
        "sentence1": "يهدف هجوم حجب الخدمة إلى جعل الخدمة غير متاحة للمستخدمين الشرعيين.",
        "sentence2": "يهدف التصيد إلى خداع المستخدم للحصول على معلومات سرية.",
        "score": 0.38,
    },
    {
        "sentence1": "تحدد سياسة أقل الصلاحيات الموارد التي يمكن للمستخدم الوصول إليها.",
        "sentence2": "تقوم المصادقة بتحديد هوية المستخدم الذي يحاول الوصول إلى النظام.",
        "score": 0.43,
    },
    {
        "sentence1": "تمثل الثغرة الأمنية نقطة ضعف يمكن استغلالها من قبل المهاجم.",
        "sentence2": "يمثل التهديد احتمال حدوث ضرر للنظام نتيجة جهة أو حدث معين.",
        "score": 0.69,
    },
    {
        "sentence1": "يستخدم Zero Trust التحقق المستمر بدلًا من افتراض الثقة بناءً على موقع المستخدم.",
        "sentence2": "تعتمد حماية الشبكات التقليدية غالبًا على الثقة النسبية داخل حدود الشبكة.",
        "score": 0.64,
    },

    {
        "sentence1": "تستخدم قواعد البيانات المفاتيح الأساسية لتمييز السجلات بشكل فريد.",
        "sentence2": "تستخدم المفاتيح الأجنبية لربط السجلات بين الجداول.",
        "score": 0.78,
    },
    {
        "sentence1": "يهدف تطبيع قواعد البيانات إلى تقليل التكرار والمشكلات الناتجة عن تحديث البيانات.",
        "sentence2": "يمكن استخدام Denormalization لتقليل عدد عمليات الربط أثناء الاستعلام.",
        "score": 0.62,
    },
    {
        "sentence1": "تسمح المعاملة بتنفيذ مجموعة من عمليات قاعدة البيانات كوحدة منطقية واحدة.",
        "sentence2": "يستخدم الفهرس لتسريع البحث عن البيانات داخل الجدول.",
        "score": 0.37,
    },
    {
        "sentence1": "تضمن خاصية Atomicity تنفيذ المعاملة بالكامل أو عدم تنفيذها.",
        "sentence2": "تضمن خاصية Durability بقاء نتائج المعاملة بعد نجاحها.",
        "score": 0.74,
    },
    {
        "sentence1": "يساعد Query Optimizer في اختيار خطة تنفيذ مناسبة للاستعلام.",
        "sentence2": "يقوم Compiler Optimizer بتحسين التعليمات بهدف زيادة كفاءة البرنامج.",
        "score": 0.48,
    },

    {
        "sentence1": "تقوم عملية ETL باستخراج البيانات وتحويلها ثم تحميلها إلى النظام المستهدف.",
        "sentence2": "تقوم عملية ELT بتحميل البيانات أولًا ثم تنفيذ التحويل داخل النظام المستهدف.",
        "score": 0.91,
    },
    {
        "sentence1": "تتعامل معالجة الدفعات مع البيانات المتراكمة على فترات محددة.",
        "sentence2": "تعالج أنظمة البث البيانات فور وصول الأحداث الجديدة.",
        "score": 0.74,
    },
    {
        "sentence1": "تستخدم بحيرة البيانات لتخزين كميات كبيرة من البيانات الخام.",
        "sentence2": "يستخدم مستودع البيانات بيانات منظمة ومجهزة للتحليل.",
        "score": 0.71,
    },
    {
        "sentence1": "يقوم Apache Spark بتنفيذ عمليات معالجة البيانات بشكل موزع.",
        "sentence2": "يستخدم Apache Kafka لنقل وتوزيع تدفقات الأحداث.",
        "score": 0.56,
    },
    {
        "sentence1": "يقوم Airflow بجدولة مهام سير العمل وإدارة الاعتماديات بينها.",
        "sentence2": "يقوم Kafka بإرسال الأحداث بين المنتجين والمستهلكين.",
        "score": 0.27,
    },

    {
        "sentence1": "تستخدم عملية Partitioning تقسيم البيانات إلى أجزاء أصغر وفق مفتاح معين.",
        "sentence2": "تستخدم عملية Compression تقليل الحجم المطلوب لتخزين البيانات.",
        "score": 0.32,
    },
    {
        "sentence1": "يساعد Data Catalog المستخدمين على اكتشاف مجموعات البيانات وفهم بياناتها الوصفية.",
        "sentence2": "يساعد Database Index على الوصول إلى السجلات بشكل أسرع.",
        "score": 0.21,
    },
    {
        "sentence1": "يوضح Data Lineage مصدر البيانات والتحويلات التي مرت بها.",
        "sentence2": "توضح Data Provenance تاريخ مصدر البيانات وكيفية انتقالها بين الأنظمة.",
        "score": 0.93,
    },
    {
        "sentence1": "تسمح Schema Evolution بتغيير بنية البيانات مع مرور الوقت.",
        "sentence2": "تسمح Version Control بتتبع التغييرات التي تحدث للملفات البرمجية.",
        "score": 0.39,
    },
    {
        "sentence1": "تجمع النافذة الزمنية في أنظمة البث الأحداث بناءً على فترة زمنية محددة.",
        "sentence2": "تجمع المهمة المجدولة البيانات لمعالجتها في وقت محدد.",
        "score": 0.47,
    },

    {
        "sentence1": "يوفر الحوسبة السحابية موارد حوسبة يمكن زيادتها أو تقليلها عند الحاجة.",
        "sentence2": "تستخدم الأنظمة الموزعة عدة أجهزة لتنفيذ عمليات مترابطة.",
        "score": 0.67,
    },
    {
        "sentence1": "تحتوي الآلة الافتراضية على نظام تشغيل يعمل داخل بيئة افتراضية.",
        "sentence2": "تعمل الحاويات عادةً باستخدام نواة نظام التشغيل المضيف.",
        "score": 0.72,
    },
    {
        "sentence1": "تزيد Horizontal Scaling عدد النسخ التي تشغل الخدمة.",
        "sentence2": "تزيد Vertical Scaling الموارد المخصصة لخادم أو نسخة موجودة.",
        "score": 0.65,
    },
    {
        "sentence1": "يستخدم Load Balancer لتوزيع الطلبات على عدة خوادم.",
        "sentence2": "يستخدم Scheduler لتحديد الموارد والمهام التي سيتم تشغيلها.",
        "score": 0.46,
    },
    {
        "sentence1": "تسمح Service Discovery للخدمات الموزعة بالعثور على بعضها.",
        "sentence2": "يسمح DNS للعملاء بالعثور على الخوادم من خلال أسماء النطاقات.",
        "score": 0.61,
    },

    {
        "sentence1": "تسمح خوارزميات الإجماع للعقد الموزعة بالاتفاق على قرار مشترك.",
        "sentence2": "تقوم عملية النسخ المتماثل بإنشاء نسخ متعددة من البيانات.",
        "score": 0.58,
    },
    {
        "sentence1": "تقوم عملية انتخاب القائد باختيار عقدة مسؤولة عن تنسيق بعض العمليات.",
        "sentence2": "يقوم موازن الحمل بتوزيع الطلبات على الخوادم المتاحة.",
        "score": 0.24,
    },
    {
        "sentence1": "يسمح Fault Tolerance للنظام بالاستمرار رغم تعطل بعض مكوناته.",
        "sentence2": "تهدف High Availability إلى تقليل الوقت الذي تكون فيه الخدمة غير متاحة.",
        "score": 0.82,
    },
    {
        "sentence1": "تعني Eventual Consistency أن النسخ قد تختلف مؤقتًا قبل أن تصل إلى حالة متوافقة.",
        "sentence2": "تعني Strong Consistency أن القراءات تعكس الحالة الصحيحة المتوقعة للبيانات.",
        "score": 0.76,
    },
    {
        "sentence1": "قد تؤدي مشكلة Network Partition إلى منع بعض العقد من التواصل مع بعضها.",
        "sentence2": "قد يؤدي انقطاع التيار الكهربائي إلى إيقاف جهاز الحاسوب بالكامل.",
        "score": 0.19,
    },

    {
        "sentence1": "تستخدم Random Forest مجموعة من أشجار القرار للحصول على تنبؤ أكثر استقرارًا.",
        "sentence2": "تستخدم Boosting نماذج متتابعة لتحسين الأخطاء التي ارتكبتها النماذج السابقة.",
        "score": 0.76,
    },
    {
        "sentence1": "يستخدم الانحدار الخطي للتنبؤ بقيم عددية مستمرة.",
        "sentence2": "يستخدم الانحدار اللوجستي غالبًا للتنبؤ باحتمال الانتماء إلى فئة.",
        "score": 0.77,
    },
    {
        "sentence1": "تبحث SVM عن حد فاصل يحقق هامشًا مناسبًا بين الفئات.",
        "sentence2": "تقوم Logistic Regression بحساب احتمالات الانتماء إلى الفئات.",
        "score": 0.57,
    },
    {
        "sentence1": "يستخدم K-Means مراكز تمثل المجموعات أثناء عملية التجميع.",
        "sentence2": "تستخدم Decision Tree عقدًا تحتوي على شروط لتقسيم البيانات.",
        "score": 0.35,
    },
    {
        "sentence1": "تكتشف خوارزميات Anomaly Detection الحالات غير المعتادة في البيانات.",
        "sentence2": "تقوم خوارزميات Classification بتعيين البيانات إلى فئات معروفة.",
        "score": 0.51,
    },

    {
        "sentence1": "يهدف Feature Selection إلى اختيار مجموعة فرعية من الخصائص.",
        "sentence2": "يهدف Feature Extraction إلى إنشاء تمثيل جديد للخصائص الأصلية.",
        "score": 0.72,
    },
    {
        "sentence1": "تضيف Regularization عقوبة إلى دالة الهدف لتقليل تعقيد النموذج.",
        "sentence2": "تستخدم Early Stopping إيقاف التدريب عندما يتوقف أداء مجموعة التحقق عن التحسن.",
        "score": 0.59,
    },
    {
        "sentence1": "تستخدم Cross Validation عدة تقسيمات للبيانات لتقييم قدرة النموذج على التعميم.",
        "sentence2": "تستخدم Bootstrap عينات يتم اختيار عناصرها مع السماح بالتكرار.",
        "score": 0.49,
    },
    {
        "sentence1": "تمثل Hyperparameters إعدادات يتم تحديدها قبل أو أثناء عملية التدريب.",
        "sentence2": "تمثل Model Parameters القيم التي يتعلمها النموذج من بيانات التدريب.",
        "score": 0.67,
    },
    {
        "sentence1": "يحدث Overfitting عندما يتعلم النموذج تفاصيل التدريب بشكل يجعله ضعيفًا على بيانات جديدة.",
        "sentence2": "يحدث Underfitting عندما يكون النموذج بسيطًا لدرجة أنه لا يتعلم الأنماط المهمة.",
        "score": 0.79,
    },

    {
        "sentence1": "تحسب Backpropagation التدرجات اللازمة لتحديث معاملات الشبكة العصبية.",
        "sentence2": "يستخدم Gradient Descent هذه التدرجات لتحديث معاملات النموذج.",
        "score": 0.89,
    },
    {
        "sentence1": "تستخدم Dropout تعطيل بعض الوحدات العصبية عشوائيًا أثناء التدريب.",
        "sentence2": "يستخدم Weight Decay عقوبة تقلل من القيم الكبيرة لمعاملات النموذج.",
        "score": 0.51,
    },
    {
        "sentence1": "تضيف دالة ReLU لاخطية من خلال جعل القيم السالبة تساوي صفرًا.",
        "sentence2": "تحول دالة Sigmoid القيم إلى نطاق بين صفر وواحد.",
        "score": 0.61,
    },
    {
        "sentence1": "تحول Softmax مجموعة من القيم إلى احتمالات مجموعها يساوي واحدًا.",
        "sentence2": "تستخدم Sigmoid لتحويل كل قيمة إلى نطاق محدود بشكل مستقل.",
        "score": 0.68,
    },
    {
        "sentence1": "تسمح الوصلات المتبقية في الشبكات العميقة بانتقال المعلومات عبر مسارات مختصرة.",
        "sentence2": "يمكن أن تساعد Skip Connections في تحسين تدريب الشبكات العصبية العميقة.",
        "score": 0.91,
    },

    {
        "sentence1": "تستخدم LSTM بوابات للتحكم في المعلومات التي يتم الاحتفاظ بها أو حذفها.",
        "sentence2": "تستخدم GRU بوابات للتحكم في تدفق المعلومات داخل الشبكة المتكررة.",
        "score": 0.84,
    },
    {
        "sentence1": "يعتمد Transformer على آلية Self-Attention لمعالجة العلاقات بين الرموز.",
        "sentence2": "يعتمد LSTM على الحالة المتكررة لنقل المعلومات بين خطوات التسلسل.",
        "score": 0.54,
    },
    {
        "sentence1": "تستخدم Positional Encoding لإضافة معلومات عن ترتيب الرموز إلى Transformer.",
        "sentence2": "تعرف الشبكات المتكررة ترتيب البيانات من خلال تسلسل العمليات المتكررة.",
        "score": 0.55,
    },
    {
        "sentence1": "يحول Encoder المدخلات إلى تمثيل داخلي يمكن للنموذج استخدامه.",
        "sentence2": "يحول Decoder التمثيل الداخلي إلى المخرجات المطلوبة.",
        "score": 0.76,
    },
    {
        "sentence1": "تستخدم الشبكات الالتفافية Filters لاكتشاف الأنماط المحلية داخل الصور.",
        "sentence2": "تستخدم الشبكات المتكررة حالات مخفية لمعالجة البيانات المتسلسلة.",
        "score": 0.31,
    },

    {
        "sentence1": "تقوم عملية Tokenization بتحويل النص إلى وحدات يمكن للنموذج معالجتها.",
        "sentence2": "تقوم عملية Sentence Segmentation بتقسيم النص إلى جمل منفصلة.",
        "score": 0.72,
    },
    {
        "sentence1": "تستخدم TF-IDF أوزانًا تعتمد على تكرار الكلمة داخل المستند وندرتها عبر المستندات.",
        "sentence2": "تمثل Word Embeddings الكلمات باستخدام متجهات كثيفة.",
        "score": 0.48,
    },
    {
        "sentence1": "تقيس Semantic Similarity مدى التقارب في المعنى بين نصين.",
        "sentence2": "تقيس Lexical Similarity مدى تشابه الكلمات المستخدمة في نصين.",
        "score": 0.73,
    },
    {
        "sentence1": "يحدد Named Entity Recognition الكيانات مثل الأشخاص والمنظمات والأماكن داخل النص.",
        "sentence2": "يحدد Part-of-Speech Tagging الوظيفة النحوية لكل كلمة.",
        "score": 0.59,
    },
    {
        "sentence1": "تقوم Sentiment Analysis بتحديد الاتجاه العاطفي للنص.",
        "sentence2": "تحاول Emotion Classification تحديد مشاعر مثل الغضب والسعادة والخوف.",
        "score": 0.82,
    },

    {
        "sentence1": "تستخدم أنظمة الترجمة الآلية نموذجًا لتحويل النص من لغة إلى أخرى.",
        "sentence2": "تقوم أنظمة تلخيص النصوص بإنتاج نسخة أقصر من المستند الأصلي.",
        "score": 0.54,
    },
    {
        "sentence1": "تستخدم أنظمة Question Answering المعلومات الموجودة في السؤال والسياق لإنتاج إجابة.",
        "sentence2": "تقوم أنظمة Text Classification بتعيين النص إلى فئة محددة.",
        "score": 0.39,
    },
    {
        "sentence1": "يمكن للتمثيلات السياقية إعطاء الكلمة نفسها متجهًا مختلفًا حسب السياق.",
        "sentence2": "تعطي التمثيلات الثابتة عادةً نفس المتجه للكلمة بغض النظر عن السياق.",
        "score": 0.77,
    },
    {
        "sentence1": "تقوم Lemmatization بتحويل الكلمات إلى أشكالها الأساسية ذات المعنى اللغوي.",
        "sentence2": "تقوم Stemming بإزالة أجزاء من الكلمة باستخدام قواعد بسيطة.",
        "score": 0.79,
    },
    {
        "sentence1": "تستخدم إزالة كلمات التوقف للتخلص من كلمات شائعة قد لا تكون مهمة لبعض مهام معالجة النصوص.",
        "sentence2": "تستخدم إزالة الضوضاء لتنظيف البيانات من العناصر غير المرغوبة.",
        "score": 0.52,
    },

    {
        "sentence1": "تحول نماذج Embedding الجمل إلى متجهات عددية في مساحة دلالية.",
        "sentence2": "تستخدم Vector Databases هذه المتجهات لإجراء عمليات البحث بالتشابه.",
        "score": 0.79,
    },
    {
        "sentence1": "يبحث Dense Retrieval عن المستندات باستخدام تمثيلات متجهية كثيفة.",
        "sentence2": "يعتمد Sparse Retrieval غالبًا على تطابق الكلمات والأوزان المعجمية.",
        "score": 0.61,
    },
    {
        "sentence1": "يستخدم Cosine Similarity الزاوية بين المتجهات لتقدير مدى تشابهها.",
        "sentence2": "يستخدم Euclidean Distance المسافة الهندسية بين نقطتين.",
        "score": 0.57,
    },
    {
        "sentence1": "تستخدم Approximate Nearest Neighbor طرقًا تقريبية لتسريع البحث عن المتجهات الأقرب.",
        "sentence2": "يفحص Exact Nearest Neighbor جميع العناصر للحصول على أقرب نتيجة بدقة.",
        "score": 0.71,
    },
    {
        "sentence1": "يمكن أن تؤثر طريقة تقسيم المستندات إلى Chunks على جودة الاسترجاع.",
        "sentence2": "يمكن أن يؤدي تقسيم المستند إلى أجزاء صغيرة جدًا إلى فقدان السياق.",
        "score": 0.87,
    },

    {
        "sentence1": "يقوم Reranker بإعادة ترتيب المستندات التي تم استرجاعها وفقًا لمدى ملاءمتها.",
        "sentence2": "يقوم Retriever بالعثور على مجموعة أولية من المستندات المرشحة.",
        "score": 0.85,
    },
    {
        "sentence1": "يستخدم Query Expansion كلمات أو مفاهيم إضافية لتحسين نتائج البحث.",
        "sentence2": "يستخدم Query Rewriting صياغة مختلفة للسؤال لتحسين الاسترجاع.",
        "score": 0.88,
    },
    {
        "sentence1": "يجمع Hybrid Retrieval بين البحث الدلالي والبحث المعتمد على الكلمات.",
        "sentence2": "يجمع Ensemble Learning تنبؤات عدة نماذج لتحسين النتيجة.",
        "score": 0.34,
    },
    {
        "sentence1": "تستخدم Metadata Filtering خصائص المستند لتحديد العناصر المسموح باسترجاعها.",
        "sentence2": "تستخدم Semantic Search المعنى لتحديد المستندات الأكثر صلة بالسؤال.",
        "score": 0.62,
    },
    {
        "sentence1": "يساعد Grounded Generation على إنتاج إجابات تستند إلى معلومات مسترجعة.",
        "sentence2": "تحدث Hallucination عندما ينتج النموذج معلومات غير مدعومة بالمصادر.",
        "score": 0.47,
    },

    {
        "sentence1": "تقوم Image Classification بتحديد الفئة التي تنتمي إليها الصورة.",
        "sentence2": "تقوم Object Detection بتحديد الأشياء ومواقعها داخل الصورة.",
        "score": 0.78,
    },
    {
        "sentence1": "تقوم Semantic Segmentation بإعطاء تصنيف لكل بكسل في الصورة.",
        "sentence2": "تقوم Instance Segmentation بتمييز كل كائن بشكل منفصل حتى لو كانت الكائنات من الفئة نفسها.",
        "score": 0.86,
    },
    {
        "sentence1": "تحول OCR النص الموجود داخل الصور إلى نص قابل للمعالجة.",
        "sentence2": "تحول Speech Recognition الكلام المنطوق إلى نص.",
        "score": 0.68,
    },
    {
        "sentence1": "يستخدم Edge Detection لاكتشاف التغيرات السريعة في شدة البكسلات.",
        "sentence2": "يستخدم Object Detection لاكتشاف الكائنات الموجودة في الصورة.",
        "score": 0.42,
    },
    {
        "sentence1": "يستخدم IoU لقياس مقدار التداخل بين صندوقين في مهام اكتشاف الكائنات.",
        "sentence2": "يستخدم Accuracy لقياس نسبة التوقعات الصحيحة في التصنيف.",
        "score": 0.17,
    },

    {
        "sentence1": "تقسم Microservices التطبيق إلى خدمات مستقلة يمكن نشرها بشكل منفصل.",
        "sentence2": "يتم نشر التطبيق Monolithic عادةً كوحدة برمجية واحدة.",
        "score": 0.72,
    },
    {
        "sentence1": "يوفر API Gateway نقطة دخول موحدة لعدد من الخدمات الخلفية.",
        "sentence2": "يعمل Reverse Proxy كوسيط بين العملاء والخوادم الخلفية.",
        "score": 0.77,
    },
    {
        "sentence1": "تستخدم Message Brokers لتبادل الرسائل بين الخدمات بشكل غير متزامن.",
        "sentence2": "تعتمد REST APIs غالبًا على نموذج الطلب والاستجابة.",
        "score": 0.45,
    },
    {
        "sentence1": "يمنع Circuit Breaker تكرار الطلبات إلى خدمة غير متاحة.",
        "sentence2": "تقوم آلية Retry بإعادة محاولة العمليات التي فشلت.",
        "score": 0.69,
    },
    {
        "sentence1": "تعني Idempotency أن تكرار العملية لا ينتج عنه تأثير إضافي غير مقصود.",
        "sentence2": "يساعد Caching على تقليل تنفيذ العمليات المكلفة بشكل متكرر.",
        "score": 0.53,
    },

    {
        "sentence1": "تستخدم Distributed Tracing لتتبع الطلب أثناء مروره عبر عدة خدمات.",
        "sentence2": "تستخدم Application Logs لتسجيل الأحداث التي تحدث أثناء تنفيذ البرنامج.",
        "score": 0.64,
    },
    {
        "sentence1": "تمثل Metrics قياسات رقمية تصف أداء النظام.",
        "sentence2": "تسجل Logs الأحداث والتفاصيل التي تحدث أثناء تشغيل النظام.",
        "score": 0.66,
    },
    {
        "sentence1": "تساعد Observability المهندسين على فهم الحالة الداخلية للنظام من خلال بيانات التشغيل.",
        "sentence2": "يستخدم Monitoring لمراقبة مؤشرات محددة وإطلاق تنبيهات عند حدوث مشكلات.",
        "score": 0.75,
    },
    {
        "sentence1": "يتحقق Health Check من قدرة الخدمة على استقبال الطلبات.",
        "sentence2": "يتحقق Unit Test من سلوك جزء صغير ومحدد من البرنامج.",
        "score": 0.35,
    },
    {
        "sentence1": "تستخدم CI لاختبار التغييرات البرمجية تلقائيًا قبل دمجها.",
        "sentence2": "تستخدم CD لأتمتة عمليات نشر البرمجيات إلى البيئات المستهدفة.",
        "score": 0.83,
    },

    {
        "sentence1": "يقوم Docker بتغليف التطبيق واعتمادياته داخل حاوية معزولة.",
        "sentence2": "تستخدم الآلة الافتراضية نظام تشغيل كامل داخل بيئة افتراضية.",
        "score": 0.72,
    },
    {
        "sentence1": "تحتوي Docker Image على الملفات والتعليمات اللازمة لإنشاء حاوية.",
        "sentence2": "تمثل Docker Container نسخة قيد التشغيل من صورة معينة.",
        "score": 0.91,
    },
    {
        "sentence1": "يقوم Kubernetes بإدارة الحاويات والخدمات عبر مجموعة من الأجهزة.",
        "sentence2": "يقوم Docker بتشغيل التطبيقات داخل حاويات معزولة.",
        "score": 0.71,
    },
    {
        "sentence1": "تخزن Container Registry صور الحاويات وتوفرها للأنظمة المختلفة.",
        "sentence2": "تخزن Package Repository حزم البرامج وإصداراتها.",
        "score": 0.51,
    },
    {
        "sentence1": "تسمح Infrastructure as Code بإدارة البنية التحتية باستخدام ملفات قابلة للتكرار.",
        "sentence2": "يسمح Version Control بتتبع التغييرات التي تحدث في الملفات.",
        "score": 0.48,
    },

    {
        "sentence1": "تستخدم Blue-Green Deployment بيئتين منفصلتين لتقليل مخاطر نشر الإصدار الجديد.",
        "sentence2": "تستخدم Canary Deployment نشر الإصدار الجديد تدريجيًا على جزء من المستخدمين.",
        "score": 0.77,
    },
    {
        "sentence1": "تقوم Rolling Deployment باستبدال النسخ القديمة تدريجيًا بنسخ جديدة.",
        "sentence2": "تقوم Blue-Green Deployment بالتبديل بين بيئتين منفصلتين.",
        "score": 0.74,
    },
    {
        "sentence1": "يقوم Horizontal Autoscaling بزيادة أو تقليل عدد نسخ الخدمة.",
        "sentence2": "يقوم Vertical Scaling بزيادة الموارد المخصصة لنسخة موجودة.",
        "score": 0.66,
    },
    {
        "sentence1": "تستخدم Service Mesh لإدارة الاتصال بين الخدمات داخل النظام الموزع.",
        "sentence2": "يستخدم API Gateway كنقطة دخول لطلبات العملاء إلى الخدمات.",
        "score": 0.58,
    },

    {
        "sentence1": "يستخدم Confusion Matrix لتلخيص نتائج التصنيف الصحيح والخاطئ.",
        "sentence2": "تستخدم Loss Function لقياس مدى خطأ توقعات النموذج.",
        "score": 0.32,
    },
    {
        "sentence1": "تقيس Precision نسبة التوقعات الإيجابية الصحيحة من جميع التوقعات الإيجابية.",
        "sentence2": "تقيس Recall نسبة الحالات الإيجابية التي نجح النموذج في اكتشافها.",
        "score": 0.76,
    },
    {
        "sentence1": "يجمع F1 Score بين Precision وRecall باستخدام المتوسط التوافقي.",
        "sentence2": "تقيس Accuracy النسبة الإجمالية للتوقعات الصحيحة.",
        "score": 0.55,
    },
    {
        "sentence1": "يحدث Data Leakage عندما تدخل معلومات من خارج وقت التنبؤ إلى عملية التدريب.",
        "sentence2": "يحدث Overfitting عندما يحفظ النموذج تفاصيل بيانات التدريب بشكل مفرط.",
        "score": 0.59,
    },
    {
        "sentence1": "يحدث Data Drift عندما يتغير توزيع خصائص البيانات التي تصل إلى النموذج.",
        "sentence2": "يحدث Concept Drift عندما تتغير العلاقة بين المدخلات والنتيجة المستهدفة.",
        "score": 0.84,
    },

]

df = pd.DataFrame(arabic_data)

df.to_csv("Arabic_semantic_similarity_dataset.csv", index=False, encoding="utf-8")

print(df)
print("\nDataset saved as 'Arabic_semantic_similarity_dataset.csv'")
# Out:
#                                              sentence1  \
# 0    تستخدم الشبكات العصبية طبقات متعددة لتحويل الم...
# 1    تقوم خوارزمية الانحدار التدريجي بتحديث معاملات...
# 2    تستخدم آلية الانتباه الذاتي العلاقات بين الكلم...
# 3    تعمل قواعد البيانات العلائقية على تنظيم المعلو...
# 4    تستخدم خوارزمية ديكسترا لإيجاد أقصر المسارات ف...
# ..                                                 ...
# 134  يستخدم Confusion Matrix لتلخيص نتائج التصنيف ا...
# 135  تقيس Precision نسبة التوقعات الإيجابية الصحيحة...
# 136  يجمع F1 Score بين Precision وRecall باستخدام ا...
# 137  يحدث Data Leakage عندما تدخل معلومات من خارج و...
# 138  يحدث Data Drift عندما يتغير توزيع خصائص البيان...
#
#                                              sentence2  score
# 0    تعتمد خوارزميات البحث الثنائي على تقسيم مساحة ...   0.08
# 1    يتم استخدام أشجار القرار لتقسيم البيانات بناءً...   0.21
# 2    يسمح الانتباه الذاتي للنموذج بالتركيز على أجزا...   0.94
# ...
